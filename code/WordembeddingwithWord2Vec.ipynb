# %% [markdown]
# # Word embedding with Word2Vec

# %% [markdown]
# Disclaimer : this notebook is a mix of our function implemented into the lab session "Week 9". A lot of cellules are taking from the lab session (Word embedding with Word2Vec).

# %% [markdown]
# ## Load data via GitHub and load required packages

# %%
#Training data and import some packages
import pandas as pd
import numpy as np
path = "https://raw.githubusercontent.com/Lirette2/DMML2021_Apple/main/data/training_data.csv"
df = pd.read_csv(path, index_col=0)
#df = pd.read_csv('/content/training_data.csv')

# %%
# Import required packages
# !python -m spacy download fr_core_news_sm

#Import fr_core_news_sm
import spacy
from spacy import displacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting fr_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-2.2.5/fr_core_news_sm-2.2.5.tar.gz (14.7 MB)
#      |████████████████████████████████| 14.7 MB 15.0 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from fr_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (2.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->fr_core_news_sm==2.2.5) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->fr_core_news_sm==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->fr_core_news_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->fr_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->fr_core_news_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->fr_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->fr_core_news_sm==2.2.5) (2.10)
# Building wheels for collected packages: fr-core-news-sm
#   Building wheel for fr-core-news-sm (setup.py) ... done
#   Created wheel for fr-core-news-sm: filename=fr_core_news_sm-2.2.5-py3-none-any.whl size=14727026 sha256=45808dc5db4c96a66e07e87aa93e7875ed583eabeafeb1598e2277c8d9b4d795
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x76d1iu4/wheels/c9/a6/ea/0778337c34660027ee67ef3a91fb9d3600b76777a912ea1c24
# Successfully built fr-core-news-sm
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')

# %%
# Import additional packages
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

from spacy.lang.fr.stop_words import STOP_WORDS
from spacy.lang.fr.examples import sentences 
from spacy.lang.fr import French
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
#Look at the data
df.head()
# Out:
#                                              sentence difficulty
# id
# 0   Les coûts kilométriques réels peuvent diverger...         C1
# 1   Le bleu, c'est ma couleur préférée mais je n'a...         A1
# 2   Le test de niveau en français est sur le site ...         A1
# 3            Est-ce que ton mari est aussi de Boston?         A1
# 4   Dans les écoles de commerce, dans les couloirs...         B1

# %%
df_pred = pd.read_csv(path, index_col=0)
df_pred.head()
# Out:
#                                              sentence difficulty
# id
# 0   Les coûts kilométriques réels peuvent diverger...         C1
# 1   Le bleu, c'est ma couleur préférée mais je n'a...         A1
# 2   Le test de niveau en français est sur le site ...         A1
# 3            Est-ce que ton mari est aussi de Boston?         A1
# 4   Dans les écoles de commerce, dans les couloirs...         B1

# %%
path = "https://raw.githubusercontent.com/Lirette2/DMML2021_Apple/main/data/sample_submission.csv"
df_example_submission = pd.read_csv(path, index_col=0)
df_example_submission.head()
# Out:
#    difficulty
# id
# 0          A1
# 1          A1
# 2          A1
# 3          A1
# 4          A1

# %% [markdown]
# ## Starting with Word Embedding with Word2Vec

# %%
# Import vocabulary librairie from spaCy
sp = !python -m spacy download fr_core_news_sm

# %%
#Import package used for Word2Vec
from gensim.models import Word2Vec

# %%
# Create a list of punctuation marks
punctuations = string.punctuation
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Create a list of stopwords
stop_words = spacy.lang.fr.stop_words.STOP_WORDS 

list(stop_words)[:10]
# Out:
# ['devant',
#  'uns',
#  'seraient',
#  'dehors',
#  'fait',
#  'certains',
#  'pur',
#  'pourrais',
#  'crac',
#  'proche']

# %%
# Load French language model
# Load French language model
import fr_core_news_sm
#sp = spacy.load('en_core_web_sm')
sp = fr_core_news_sm.load()

# Create tokenizer function
def spacy_tokenizer(sentence):
    # Create token object, which is used to create documents with linguistic annotations.
    mytokens = sp(sentence)

    # Lemmatize each token and convert each token into lowercase
    mytokens = [ word.lemma_.lower().strip() for word in mytokens ]

    # Remove stop words and punctuation
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # Return preprocessed list of tokens
    return mytokens

# Example
#New_sentence = df["sentence"].sample()
New_sentence = df["sentence"].head()
New_sentence.values[0]
# Out:
# "Les coûts kilométriques réels peuvent diverger sensiblement des valeurs moyennes en fonction du moyen de transport utilisé, du taux d'occupation ou du taux de remplissage, de l'infrastructure utilisée, de la topographie des lignes, du flux de trafic, etc."

# %%
spacy_tokenizer(New_sentence.values[0])
# Out:
# ['coût',
#  'kilométrique',
#  'réel',
#  'pouvoir',
#  'diverger',
#  'sensiblemer',
#  'valeur',
#  'moyenner',
#  'fonction',
#  'moyen',
#  'transport',
#  'utiliser',
#  'taux',
#  'occupation',
#  'taux',
#  'remplissage',
#  'infrastructure',
#  'utiliser',
#  'topographie',
#  'ligne',
#  'flux',
#  'trafic',
#  'etc.']

# %%
#Vectorization Feature Engineering (TF-IDF)
tfidf_vector = TfidfVectorizer(tokenizer=spacy_tokenizer) # we use the above defined tokenizer

# %%
texts = df['sentence']

# %%
# Create tokenizer function for preprocessing
def spacy_tokenizer(text):

    # Define stopwords, punctuation, and numbers
    stop_words = spacy.lang.fr.stop_words.STOP_WORDS
    punctuations = string.punctuation
    numbers = "0123456789"

    # Create spacy object
    mytokens = sp(text)

    # Lemmatize each token and convert each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Remove stop words and punctuation
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # Remove sufix like ".[1" in "experience.[1"
    mytokens_2 = []
    for word in mytokens:
      for char in word:
        if (char in punctuations) or (char in numbers):
          word = word.replace(char, "")
      if word != "":
        mytokens_2.append(word)

    # Return preprocessed list of tokens
    return mytokens_2

# Tokenize texts
processed_texts = []
for text in texts:
  processed_text = spacy_tokenizer(text)
  processed_texts.append(processed_text)

# %%
#Use this lines only if we want to check
#for processed_text in processed_texts:
#  print(processed_text[:20])
# Out:
# ['coût', 'kilométrique', 'réel', 'pouvoir', 'diverger', 'sensiblemer', 'valeur', 'moyenner', 'fonction', 'moyen', 'transport', 'utiliser', 'taux', 'occupation', 'taux', 'remplissage', 'infrastructure', 'utiliser', 'topographie', 'ligne']
# ['bleu', 'couleur', 'préférer', 'aime', 'vert']
# ['test', 'niveau', 'français', 'site', 'internet', 'école']
# ['mari', 'boston']
# ['école', 'commerce', 'couloir', 'place', 'financier', 'arrive', 'croiser', 'jeune', 'adulte', 'an', 'prévoir', 'ouvrir', 'maison', 'hôte', 'quinzaine', 'année']
# ['histoire', 'aimer']
# ['médecin', 'devoir', 'boire', 'verre', 'vin', 'rouge', 'repas']
# ['observer', 'besoin', 'popularité', 'développé', 'considérer', 'moindre', 'signal', 'smartphone', 'indicateur', 'degré', 'popularité']
# ['retrouver', 'plaisir', 'manger', 'oeuf', 'coque']
# ['aller', 'habiter', 'petit', 'maison', 'ancien', 'trè', 'jardin']
# ['bonjour', 'bon', 'année']
# ['presse', 'abondamment', 'faire', 'écho', 'secondaire', 'ressentir', 'soignant', 'an']
# ['rocher', 'ouvrir', 'falloir', 'toucher', 'brin', 'herbe']
# ['habite', 'bel', 'ville', 'nord', 'france']
# ['devoir', 'répondre', 'goût', 'consommateur', 'al', 'capacité', 'portemonnaie']
# ['timidité', 'quitter', 'éloigner', 'ellénore', 'reprendre', 'plan', 'habile', 'profonde', 'combinaison', 'peine', 'retrouvais', 'auprès', 'sentir', 'tremblant', 'troublé']
# ['fréquenter', 'galerie', 'meilleur', 'manière', 'éduquer', 'oeil', 'art', 'contemporain']
# ['soir', 'cuche', 'tôt', 'devoir', 'bon', 'forme']
# ['mère', 'raphaël', 'vanessa', 'exprime', 'satisfaction', 'enfant', 'posséder', 'portable', 'libérer', 'ligne', 'déclare', 't']
# ['faire', 'grandchose', 'maison']
# ['ajoute', 'interdiction', 'total', 'impossible', 'gérer']
# ['hésitation', 'tourner', 'gauche', 'sonner', 'terre', 'durcir', 'bruit', 'cadencé', 'monotone', 'assoupir', 'berçant', 'tumulte', 'esprit']
# ['signale', 'expression', 'lingua', 'franca', 'français', 'langue', 'international', 'égard', 'rayonnement', 'politique', 'culturel']
# ['téléphoner', 'travail']
# ['pouvoir', 'chercher']
# ['pouvoir', 'poser', 'problème', 'petit', 'livret', 'pourtant', 'attractif', 'pourcent', 'détenteur', 'arriver', 'bout']
# ['consulte', 'habitude', 'messagerie', 'prendre', 'café']
# ['train', 'dîner']
# ['trouve', 'éducation', 'bon', 'chose']
# ['besoin', 'chose']
# ['perpétuel', 'clandestin', 'munir', 'faux', 'titre', 'séjour', 'photocopie', 'carte', 'résident', 'copain', 'complice', 'ensuite', 'sillonner', 'hexagone', 'bon', 'vouloir', 'employeur', 'scrupuleux']
# ['mariage', 'mixte', 'apparaît', 'lieu', 'privilégier', 'culture', 'affronter', 'dialoguent', 'fondre']
# ['assis', 'terrasse', 'quartier', 'touristique', 'vieux', 'lyon', 'james', 'sirote', 'limonade', 'fraîche']
# ['chronologie', 'antique', 'prendre', 'sens', 'large', 'pourtour', 'méditerranée', 'découpage', 'spatial', 'pertinent', 'entité', 'géographique', 'période', 'mer', 'intérieure', 'vivre', 'limite']
# ['obscur', 'devenons', 'maître', 'biosphère', 'devenon', 'dépendant', 'dégradon', 'dégrader', 'vies']
# ['début', 'trouble', 'poursuivre', 'étendre', 'territoire', 'long', 'mois', 'septembre', 'fameuse', 'journéer', 'septembre', 'amplifié', 'refus', 'guillaume', 'considérer', 'revendication', 'insurgé']
# ['fille', 'faire', 'collier', 'fruit', 'rouge', 'ressembler', 'perle']
# []
# ['revenu', 'devient', 'nécessité', 'homme', 'pouvoir', 'accéder', 'satisfaction', 'combler', 'désir']
# ['taire', 'mangeas', 'petit', 'fruit', 'eus', 'cueillir']
# ['ben', 'débordés']
# ['petit', 'garçon', 'ben', 'nid', 'y']
# ['forme', 'matinée']
# ['ordinateur', 'pouvoir', 'répondre', 'interruption', 'permettre', 'exécuter', 'programme', 'réponse', 'spécifique', 'reprendre', 'exécution', 'séquentielle', 'programme', 'interrompre']
# ['pleuvoir', 'attendre', 'autobus']
# ['cas', 'agir', 'limite', 'relatif', 'baser', 'taux', 'croissance', 'démographique', 'référence', 'valable', 'uniquement', 'centre', 'pondérer', 'fonction', 'degré', 'centralité']
# []
# ['pourcent', 'déchet', 'entreprise', 'faire', 'objet', 'collecte', 'sélectif']
# ['médecin', 'donneur', 'conseiller', 'volontier', 'cas', 'renseigner', 'rapport', 'al', 'don', 'sang']
# ['inquiétant', 'scandinavie', 'déjà', 'battre', 'record', 'chaleur']
# ['aime', 'ski']
# ['malheureusement', 'évident', 'y', 'voie', 'obtenir', 'confirmation', 'écrire', 'neera', 'tanden', 'joe', 'biden', 'retirer', 'candidature']
# ['oisillon', 'retrouve', 't', 'forêt']
# ['naître', 'jour']
# ['existe', 'effectivement', 'humain', 'posséder', 'quantité', 'pouvoir', 'important', 'contraindre', 'humanité', 'travailler', 'créer', 'cercle', 'vicieux', 'faire', 'travail', 'nécessité', 'accéder', 'propre', 'désir']
# ['bouchée', 'expression', 'faire', 'référence', 'quantité', 'aliment', 'mettre', 'bouche', 'fois']
# ['respecter', 'indication', 'sérieusement', 'trouver', 'facilement', 'chemin', 'travers', 'ruelle']
# ['aussitôt', 'julie', 'découvrir', 'vérité', 'furieux']
# ['pile', 'momer', 'besoin', 'réconfort']
# ['train', 'temps', 'également', 'craindre', 'brigitte', 'munier', 'robot', 'susciter', 'enthousiasme', 'occidental', 'angoisse', 'lieu', 'concevoir', 'simple', 'outil', 'manière', 'japonais', 'amicau', 'auxiliaire', 'craindre']
# ['venir', 'emménager', 'maison']
# ['année', 'défile']
# ['compte', 'configuration', 'zone', 'adapter', 'mesure', 'terrain', 'limiter', 'diffusion', 'campagnol', 'terrestre', 'axe', 'routier', 'représenter', 'barrière', 'fort', 'espèce', 'pouvoir', 'penser', 'résultat', 'artéfact']
# ['mûre', 'réflexion', 'commission', 'européen', 'idée', 'brillant', 'attaquer', 'chantier', 'bizarrement', 'échappé', 'sagacité', 'légendaire']
# ['expérience', 'télévendeur', 'pouvoir', 'devenir', 'animateur', 'pôle', 'télévendeur', 'superviseur', 'équipe', 'chef', 'plateau']
# ['taire', 'aller', 'faire']
# ['valorisation', 'boursier', 'société', 'internet', 'amazon']
# ['entendre', 'série', 'détonation', 'tandis', 'contestataire', 'scandaient', 'révolte', 'devoir', 'réussir']
# ['baby', 'boomer', 'convaincre', 'pouvoir', 'recommencer', 'an']
# ['leste', 'briller', 'ordonner', 'armée']
# ['appelle']
# ['larguer', 'sond', 'européen', 'rosetta', 'petit', 'robot', 'atterrir', 'mercredi', 'fin', 'midi', 'noyau', 'comète', 'tchourioumov', 'guérassimenko', 'histoire', 'spatial']
# ['pendre', 'linge', 'dossier', 'chaise', 'demeurer', 'tourner', 'examiner', 'meuble', 'frapper', 'stupeur', 'larme', 'couler', 'rester', 'sou', 'gardé', 'lavoir', 'entendre', 'rire', 'fenêtre', 'étienne']
# ['sérum', 'pâtir', 'comparaison', 'concurrent', 'pfizer', 'moderna', 'considérer', 'efficace', 'prévenir', 'risque', 'hospitalisation']
# ['identifier', 'peur', 'fondamentale', 'robot', 'crainte', 'instinctif', 'métal', 'chair', 'crainte', 'sociétal', 'presque', 'désespérer', 'robot', 'aller', 'voler', 'travail', 'homme', 'crainte', 'identitaire', 'voir']
# ['pouvoir', 'préférer', 'assassin', 'échec', 'annale', 'kangourou', 'edition', 'kangourou']
# ['faire', 'randonnée']
# ['y', 'pays', 'francophone']
# ['déjà', 'obligation', 'ramener']
# ['oui', 'donner', 'nom']
# ['joindre', 'formulaire', 'pièce', 'justificatif', 'document', 'format', 'numérique']
# ['bon', 'voyage']
# ['geste', 'presque', 'insensible', 'faire', 'courir', 'tête', 'al', 'pied', 'grand', 'frisson', 'peau', 'tourner', 'vivement', 'jeter', 'chercher', 'bouche', 'lèvre', 'chair', 'nue', 'main']
# ['clabaude', 'al', 'esgourder', 'blaireau', 'enfariner', 'tordu', 'pasteuriser']
# ['compagne', 'an', 'cadette', 'vivre', 'renaissance']
# ['jurer', 'introduction', 'informatique', 'enseignement', 'obligatoire', 'peur', 'veuille', 'transformer', 'primaire', 'grand', 'école', 'informatique', 'existe', 'pourtant', 'piste', 'initier', 'enseignant', 'favoriser', 'passage', 'périscolaire']
# ['acteur', 'commerce', 'équitable', 'falloir', 'distinguer', 'organisme', 'labellisateur', 'certifier', 'filière', 'importation', 'produit', 'importateur', 'grossiste', 'détaillant', 'réseau', 'boutique', 'artisans', 'monde', 'propre', 'contact']
# ['pouvoir', 'ouvrir', 'réflexion', 'finalement', 'devenir', 'enrichissant']
# ['paysan', 'pleurait', 'prétendre', 'prendre', 'fabrice', 'donner', 'écu', 'trouver', 'avoine']
# ['limite', 'instrument', 'contingentement', 'spatial', 'prendre', 'compte', 'donnent', 'idée', 'maîtrise', 'potentiel', 'urbanisation', 'maîtrise', 'dériver', 'possibilité', 'fournir', 'cadre', 'légal', 'stratégique', 'canton', 'doter']
# ['petit', 'chat', 'pleuvoir', 'parent']
# ['prémunir', 'altération', 'donnée', 'certitude', 'modifier', 'stockage', 'traitement', 'contribue', 'qualité', 'prise', 'décision', 'baser']
# ['joueur', 'joués']
# ['lu', 'découvrir', 'chose', 'surprenant', 'locataire', 'occuper', 'appartement']
# ['chose', 'intelligent']
# ['ami', 'répondre', 'téléphone']
# ['frère', 'patrice', 'jeune']
# ['vacance', 'y', 'partie', 'île']
# ['y', 'nuage', 'neige', 'tombe', 'aller', 'neiger', 'pouvoir', 'y', 'brouillard', 'risque', 'congélation', 'glace', 'température']
# ['escalier', 'conduire', 'large', 'coursiv', 'hauteur', 'faire', 'tour', 'bâtiment', 'desservir', 'succession', 'bureau']
# ['chercher', 'simple', 'annonce', 'recruteur', 'sûr', 'rater', 'offre', 'emploi', 'grâce', 'système', 'alerte', 'personnalisé']
# ['coûté', 'argent', 'énerve', 't']
# ['appeler']
# ['fabrice', 'peine', 'âgé', 'an', 'représenter', 'fort', 'chef', 'maison']
# ['oui', 'paris', 'jour', 'peine']
# ['apprentissage', 'code', 'largement', 'culture', 'général', 'numérique', 'école', 'mesure', 'réclamer', 'académie', 'science', 'soutenir', 'acteur', 'compter', 'secteur', 'numérique', 'cnil', 'conseil', 'national', 'numérique']
# ['donner', 'serviette', 'déjà', 'plan']
# ['rentre', 'demande', 'parent', 'pouvoir', 'appeler']
# ['important', 'évidemment', 'contribuable', 'européen', 'vouloir', 'annuler', 'dette', 'créditeur', 'créancier', 'traiter']
# ['ambassadeur', 'birman', 'nations', 'unie', 'kyaw', 'moe', 'tun', 'rompre', 'manière', 'spectaculaire', 'général', 'putschiste', 'semaine', 'appeler', 'mettre', 'fin', 'coup', 'etat']
# ['directeur', 'donner', 'consigne', 'personnel']
# ['regard', 'observer']
# ['auteur', 'spéculer', 'aspect', 'personnalité', 'léonard']
# ['conséquence', 'nature', 'gravissime', 'océan', 'contenir', 'revue', 'américain', 'science', 'million', 'tonne', 'déchet', 'plastique']
# ['million', 'citadin', 'rêvent', 'refaire', 'vie', 'al', 'champ', 'passer', 'pourtant', 'acte', 'y', 'événement', 'déclencheur', 'constate', 'directrice', 'changer']
# ['père', 'observer', 'convenance', 'extérieur', 'permettait', 'fréquemment', 'propos', 'léger', 'liaison', 'amour', 'regarder', 'amusement', 'permettre', 'excusable', 'considérer', 'mariage', 'rapport', 'sérieux']
# ['offrir', 't', 'part', 'ennui', 'grosse', 'boule', 'angoisse', 'creux', 'ventre']
# ['pavillon', 'mitoyen', 'paris', 'pratiquement', 'acheter']
# ['émigration', 'galicien', 'soustendre', 'évolution', 'peuplement', 'explique', 'grand', 'partie']
# ['tanière', 'fondre', 'nature', 'quasiment', 'invisible']
# ['homme', 'croire', 'libre', 'contraindre', 'déterminer', 'nature']
# ['falloir', 'radicalement', 'changer', 'cap', 'choisir', 'cuisine', 'qualité', 'accessible', 'grand', 'nombre', 'lieu', 'replier', 'valeur', 'sûr', 'désuet', 'indigeste']
# ['prophétie', 'y', 'bison', 'sauvage', 'survivre']
# ['appelle', 'camille', 'étais', 'enfant', 'rêve', 'tête']
# ['réaffirmer', 'sénat', 'livrer', 'chantage', 'contrairement', 'al', 'allégation', 'rapporteur', 'assemblée', 'national', 'contraire', 'affirmer', 'position', 'haute', 'assembler', 'relever', 'conception', 'cohérent', 'constante', 'société']
# ['coup', 'battoir', 'partir', 'espacé', 'milieu', 'rire', 'adouci', 'conversation', 'empâter', 'bruit', 'glouton', 'mâchoire', 'tandis', 'machine', 'vapeur', 'aller', 'train', 'repos', 'trêve', 'semblait']
# ['bonheur']
# ['oublier', 'personnel', 'milieu', 'scolaire', 'applique', 'déjà', 'mesure']
# ['association', 'promotion', 'développement', 'apprentissage', 'ligne', 'note', 'calculatrice', 'supplanter', 'calcul', 'mental', 'y', 'opération', 'basique', 'utilisation', 'ordinateur', 'relier', 'internet', 'pouvoir', 'aisément', 'remplacer']
# ['petit', 'oiseau']
# ['santé', 'dégrader', 'cause', 'infection', 'sévère', 'jour', 'compter']
# ['chose', 'venir', 'certifier']
# ['nouvelle', 'faire', 'grand', 'bruit', 'affaire', 'couvrefeu', 'cache', 'angoisse', 'profond']
# ['plaisir', 'annoncer', 'demande', 'inscription', 'université', 'strasbourg', 'année', 'master', 'science', 'société', 'accepter']
# ['large', 'majorité', 'français', 'favorable', 'modification', 'calcul', 'retraite', 'fonctionnaire', 'cadre', 'réforme', 'préparation', 'sondage', 'publier', 'vendredi']
# ['jeune', 'heureux', 'réussir', 'acheter', 'autonomie', 'tranquillité', 'réussite', 'lycer', 'dévore']
# ['fois', 'finir', 'théo', 'pouvoir', 'aller', 'jouer', 'amuser', 'dîner', 'parent']
# ['bel', 'âge', 'gagne', 'profondeur', 'bienveillance', 'constate', 'philippe', 'wattier']
# ['chiffre', 'publier', 'jour', 'donner', 'idée', 'dégradation', 'climat', 'élève', 'sexe']
# ['différence', 'apparaît', 'fin', 'cursus', 'scolaire', 'garçon', 'prendre', 'domaine', 'avantage', 'fille']
# ['vert', 'exemple', 'couleur', 'herbe', 'feuille', 'arbre']
# ['ressemble', 'fille', 'connaître']
# ['masse', 'liquide', 'transporter', 'grand', 'espèce', 'connu', 'mammifère', 'pouvoir', 'recèlent', 'mollusque', 'incomparable', 'taille', 'crustacé', 'effrayant', 'contempler', 'homard', 'mètre', 'crabe', 'peser', 'tonne']
# ['force', 'constater', 'écart', 'creuse', 'pays', 'développement', 'progressivement', 'sortent', 'pénurie', 'chronique', 'stagner', 'régresser', 'combat', 'faim']
# ['édition', 'dominer', 'duel', 'sommet', 'alex', 'thomson', 'cours', 'poursuite', 'mener', 'armel', 'novembre', 'jour', 'haute', 'tension', 'terminer']
# ['pouvoir', 'entrer', 'chambre']
# ['bientôt']
# ['comparaison', 'tacitement', 'inlassablement', 'répéter', 'toil', 'y', 'introduire', 'puissante', 'multiforme', 'unité', 'cause', 'clairement', 'apercevoir', 'enthousiasme', 'exciter', 'amateur', 'peinture', 'elstir']
# ['soyon', 'sérieux']
# ['bienheureux', 'quidam', 'débarrasser', 'peur', 'originel', 'échouer', 'faire', 'faux']
# ['prendre', 'train']
# ['lettre', 'schuller', 'extraite', 'correspondance', 'spinoza', 'dénoncer', 'illusion', 'libre', 'arbitre']
# ['prendre', 'petitdéjeuner', 'cuisine']
# ['arrive', 'procéder', 'temps', 'temps']
# ['cours', 'paléolithique', 'diffusion', 'fractionner', 'écoumène', 'petit', 'groupe', 'tendance', 'fin', 'glaciation', 'épaississement', 'relation', 'ancien', 'monde', 'augmentation', 'effectif', 'tissage', 'interconnexion']
# ['or', 'croissance', 'démographique', 'concerne', 'pays', 'voie', 'développement', 'connaître', 'problème', 'sousalimentation', 'mauvais', 'alimentation']
# ['chambre']
# ['indéniable', 'sérénité', 'refléter', 'trait']
# ['jour', 'an', 'correspondre', 'janvier']
# ['féru', 'art', 'yves', 'saint', 'laurent', 'constituer', 'fil', 'année', 'important', 'collection', 'objet', 'précieux', 'peinture', 'inspirer', 'création']
# ['creux', 'dominer', 'côté', 'talus', 'pied', 'haut']
# ['comprendre']
# ['partir', 'moment', 'écouter', 'choeur', 'convié', 'scène', 'ashton', 'valet', 'grand', 'duo', 'ré', 'majeur', 'passer', 'éloignement', 'instrument', 'devenu', 'sonore', 'personnage', 'reculé', 'rappeler']
# ['esprit', 'recevoir', 'instruction', 'organe', 'diversement', 'impressionner', 'comprennent', 'analysent', 'juger', 'appartenir', 'race']
# ['concrète', 'pouvoir', 'temps', 'rêve', 'terminus', 'écrivain', 'pouvoir', 'justifier', 'endurer', 'souffrance', 'inciter', 'rompre', 'temps', 'vagabondage']
# ['explorer', 'meilleur', 'voie', 'légal', 'probablement', 'système', 'interaméricain', 'invoquer', 'déclaration', 'droit', 'homme']
# ['comptelà', 'cours', 'langue', 'collège', 'pouvoir', 'profitablement', 'remplacer', 'séance', 'mémorisation', 'annuaire']
# ['préférer', 'bijou']
# ['veste']
# ['inconvénient', 'interdiction', 'risque', 'priver', 'adolescent', 'apprentissage', 'utilisation', 'raisonner', 'internet', 'réseau', 'social']
# ['massacre', 'commémorer', 'drapeau', 'ville', 'chicago', 'étoil', 'rouge']
# ['trouve', 'rue', 'marché']
# ['fruit', 'pensée', 'élaborer', 'renaissance', 'individualisme', 'projet', 'société', 'devoir', 'trouver', 'meilleur', 'condition', 'réalisation', 'épanouissement']
# ['année', 'million', 'élève', 'reprendre', 'chemin', 'école']
# ['sébastien', 'granet', 'hélène', 'lavoie', 'cheffe', 'accueillir', 'autobus', 'visiteur', 'ripailler']
# ['parent', 'mal', 'couper', 'cordon', 'étonner', 'enfant', 'préfèrent', 'brancher', 'boîte', 'vocal', 'répondre', 'appel']
# ['demander', 'président', 'république', 'parole', 'soumette', 'filtre', 'proposition', 'convention', 'référendum', 'parlement', 'application', 'réglementaire', 'direct']
# ['trouve', 'clé', 'maison']
# ['industriel', 'polluer', 'eau', 'air', 'sol', 'produit', 'toxique']
# ['mettre', 'costume', 'chapeau']
# ['élection', 'présidentiel', 'vote', 'front', 'national', 'autant', 'jeune', 'électeur', 'aîné']
# ['sondage', 'publier', 'mai', 'bva', 'société', 'français', 'sondage', 'syntec', 'numérique', 'fédération', 'professionnel', 'secteur', 'informatique', 'favorable', 'mesure', 'pourcent', 'français', 'accord', 'programmation', 'informatique']
# ['parent', 'banlieue', 'organiser', 'devoir', 'enfant']
# ['attendre', 'surprise', 'parent', 'eurent', 'promettre']
# ['duo', 'grand', 'chose', 'commun', 'mettre', 'part', 'position', 'conservateur', 'valoir', 'foudre', 'progressiste']
# ['or', 'langue', 'exister', 'actuellement', 'monde', 'moitié', 'compte', 'locuteur', 'quart']
# ['passant', 'presser', 'attarder', 'facilement', 'devanture', 'dansles', 'rayon']
# ['appartenir', 'chien', 'aboyer', 'nuit', 'jour']
# ['savoir', 'anglais', 'espagnol']
# ['phénomène', 'apparition', 'génération', 'inédit']
# ['ambiance', 'luxe', 'ici', 'tranquille', 'village']
# ['chiffre', 'tirer', 'enquête', 'sujet', 'réaliser', 'publier', 'institut', 'recherche', 'économie', 'éducation', 'auprès', 'parent', 'enfant', 'académie']
# ['monet', 'peindre', 'portrait', 'emplit', 'sensualité', 'lourd', 'symbolisme']
# []
# ['oui', 'ouragan', 'toucher', 'terre', 'nuit', 'nord', 'nicaragua', 'ensuite', 'étendre', 'pays', 'amérique', 'central']
# ['venir', 'emménager', 'maison']
# ['savoir', 'choisir', 'logement', 'idéal', 'pouvoir', 'prendre', 'mois']
# ['habitant', 'région', 'y', 'vouloir', 'revenir', 'vouloir']
# ['apporter', 'argument', 'experimental', 'théorique', 'faveur', 'mecanisme', 'intramoleculair']
# ['choisir', 'date', 'lieu', 'projet', 'intéresser', 'paie', 'part']
# ['campagne']
# ['groupe']
# ['salle', 'craquer', 'recommencer', 'strette', 'entier', 'amoureux', 'fleur', 'tombe', 'serment', 'exil', 'fatalité', 'espérance', 'pousser', 'adieu', 'final', 'emma', 'jeter', 'cri', 'aigu', 'confondre']
# ['président', 'promettre', 'promesse']
# ['aller', 'faire', 'demain']
# ['trouve', 'supermarché']
# ['donner', 'feuille', 'alouette', 'ordonner', 'tomber', 'tête', 'dragon']
# ['conseille', 'écouter', 'fois', 'histoire', 'passer', 'suite']
# ['an', 'vie', 'parisien', 'ancien', 'designer', 'graphiste', 'décider', 'consacrer', 'passion', 'cuisine']
# ['vouloir', 'voir', 'disputer', 'fois', 'vus']
# ['france', 'anglais', 'fils', 'mathia', 'répondre', 'français']
# ['mangeon', 'ensemble', 'samedi', 'soir']
# ['vouloir', 'sapeur', 'pompier']
# ['sexagénaire', 'jeune']
# ['vieux', 'chef', 'raison', 'al', 'dieux']
# ['chercher', 'joindre', 'y', 'heure']
# ['nécessite', 'équipement', 'suffisamment', 'place']
# ['soif']
# ['léonard', 'vinci', 'ami', 'reconnaître', 'domaine', 'respectif', 'influence', 'important', 'histoire']
# ['incarnation', 'mettre', 'présence', 'immuable', 'chose', 'général', 'immuable', 'revêtir', 'caractère', 'individualité', 'caractère', 'devenir', 'chose', 'universel']
# ['réduction']
# ['aime', 'pluie', 'vacance']
# ['ravir', 'accueillir']
# ['petit', 'chat', 'plaire', 'parent']
# ['enfant', 'séparer', 'mère', 'trouve', 'doudou', 'moyen', 'rassurer', 'smartphone', 'objet', 'transitionnel', 'permettre', 'lutter', 'frustration', 'affect', 'négatif', 'provoquer', 'monde', 'social']
# ['twitter', 'aller', 'bannir', 'utilisateur', 'cas', 'désinformation', 'répéter', 'vaccin']
# ['manière', 'général', 'indiscutable', 'meilleur', 'joueur', 'monde']
# ['fin', 'grand', 'récit', 'largement', 'lieux', 'classer', 'étapes', 'succession', 'mode', 'production', 'marxiste', 'représenter', 'version', 'formaliser', 'sousdéveloppement', 'décollage', 'inscrire', 'paradigme', 'évolutionniste']
# ['ici', 'travail', 'châtiment', 'divin', 'imposer', 'dieu', 'al', 'homme', 'punir', 'désobéissance']
# ['considérer', 'forcément', 'cyberaddict', 'pouvoir', 'inspirer', 'technique', 'y', 'puiser', 'conseil']
# []
# ['savoir', 'voir', 'père', 'jamais', 'demander']
# ['étape', 'caractériser', 'difficulté', 'éprouver', 'couple', 'choix', 'impose', 'éducation', 'enfant', 'école', 'religion', 'langue']
# ['inaltérable', 'patienc', 'robot', 'instituteur', 'corée', 'nord', 'japon', 'convier', 'al', 'enfant', 'autiste', 'savoir', 'évolueront', 'enfant', 'apprendre', 'composer', 'humeur', 'professeur', 'humain']
# ['communauté', 'scientifique', 'apprécier', 'présence', 'femme']
# ['ancien', 'génération', 'conservateur', 'jeune', 'génération']
# ['ete', 'maison']
# ['rencontrer']
# ['jurer', 'introduction', 'informatique', 'enseignement', 'obligatoire', 'peur', 'veuille', 'transformer', 'primaire', 'prépa', 'ecole', 'existe', 'pourtant', 'piste', 'initier', 'enseignant', 'favoriser', 'passage', 'périscolaire', 'scolaire']
# ['message', 'urgence', 'pompier', 'vient', 'tomber']
# ['lycéen', 'pompier', 'fois']
# ['journaliste', 'art', 'press', 'interviewer', 'agathe', 'performance', 'participer']
# ['croire', 'enfant', 'aller', 'réussir']
# ['vrai', 'bon', 'peur', 'tombe', 'malade']
# ['accord', 'samedi', 'venir', 'soeur', 'katrine']
# ['cyanobactérie', 'distinguer', 'bactérie', 'présence', 'chlorophylle', 'pigment', 'accessoire', 'hydrosoluble', 'phycobiline', 'rouge', 'bleu']
# ['influer', 'recherche', 'scientifique', 'milieu', 'xvii', 'siècle', 'pouvoir', 'attribuer', 'grand', 'naturaliste', 'réaumur', 'mérite', 'tirer', 'conséquence', 'expérimental', 'recherche', 'prolongation', 'vie', 'insecte']
# ['université', 'étude', 'focaliser', 'pourcent', 'étudiant', 'doctorat', 'occuper', 'fonction', 'académique']
# ['boir', 'chaud', 'donne', 'chaud', 'mal', 'température', 'élevé', 'liquide', 'augment', 'température', 'interne', 'corps', 'stimule', 'transpiration']
# ['soir', 'venir', 'falloir', 'rentrer', 'prendre', 'chemin', 'matin']
# ['vraiment', 'flow']
# ['élastique', 'distendre']
# ['auteur', 'lu', 'grammaire', 'impertinent', 'propose', 'jeu', 'lire', 'vite', 'retz']
# ['coutume', 'similaire', 'exister', 'finistère', 'enfant', 'amuser', 'creuser', 'betterave', 'moment', 'toussaint', 'faire', 'peur', 'al', 'voisinage']
# ['ressemble', 'bébé', 'tigre', 'tigre', 'peur']
# ['indicateur', 'permettre', 'évolution', 'situation', 'fur', 'mesure', 'épidémie', 'propager', 'outil', 'deviennent', 'nécessaire', 'vision', 'global', 'situation']
# ['alice', 'chien']
# ['pierre', 'roule', 'amasser', 'mousse']
# []
# ['réponse', 'al', 'question', 'pose']
# ['responsable', 'service', 'confirmer', 'condition', 'accueil', 'délivrance', 'document', 'administratif', 'mit', 'respecter', 'norme', 'établir', 'ministère']
# ['ensemble', 'jeune']
# ['prendre', 'bel', 'valise', 'vert', 'trimballe', 'an', 'passer', 'jour', 'vacance', 'vanne', 'vieux', 'amie', 'sylvaine', 'voir', 'vivre', 'valencienne']
# ['ensuite', 'ira', 'cinémer', 'quartier', 'organise', 'an', 'séance', 'spécial']
# ['résultat', 'étude', 'métrique', 'utiliser', 'entreprise', 'évaluer', 'capital', 'intellectuel']
# ['ville', 'entier', 'illuminer', 'autour', 'marché', 'noël', 'encher', 'passant', 'illumination', 'réchauffer', 'coeur', 'froid', 'hiver']
# ['intéresser', 'appelez']
# ['retraite', 'quinquagénaire', 'aujourd', 'imaginent', 'actif', 'forcément', 'actif']
# ['père', 'mutation', 'venir', 'travailler', 'paris']
# ['pouvoir', 'aller', 'théâtre', 'musée', 'cinéma']
# ['bureau', 'aller', 'rentrer', 'tard']
# ['aller', 'manger', 'jardin']
# ['vider', 'barrique', 'entier', 'sembler', 'manger', 'boeuf', 'étrangler', 'lion']
# ['feuille', 'pris', 'arbre', 'paradis', 'écrire', 'mot', 'lettre', 'or', 'père', 'éternel']
# ['inquiéter', 'vite', 'habituer', 'vie']
# ['réseau', 'social', 'objet', 'étonnant', 'paradox']
# ['enrichissement', 'culturel', 'enfant', 'pouvoir', 'ouvrir', 'travers', 'langue', 'trait', 'typologique', 'présent', 'langue', 'bilinguisme', 'breton', 'français', 'offrir', 'accès', 'indirect']
# ['étudier', 'réussi', 'facilement']
# ['journal', 'expliquer', 'prisonnier', 'évadé']
# ['connaître', 'demande', 'collègue']
# ['anecdote', 'révélatrice']
# ['année', 'centaine', 'millier', 'baby', 'boomer', 'naître', 'pic', 'naissance', 'arriver', 'retraite']
# ['y', 'aller', 'descendre', 'station', 'muser', 'louvre', 'prendre', 'droite', 'continuer', 'droit']
# ['originalité', 'mécanisme', 'utiliser', 'photon', 'convertir', 'énergie', 'chimique', 'retrouve', 'énergie', 'liaison', 'atome', 'carbone', 'hydrogène', 'glucide', 'former']
# ['pourcent', 'adolescent', 'déclarer', 'dévaster', 'devoir', 'quitter', 'foyer', 'jour', 'téléphone']
# ['cuisinier']
# ['mélangeant', 'pouvoir', 'former', 'couleur', 'vert', 'exemple', 'couleur', 'herbe', 'feuille', 'arbre']
# ['haut', 'conseil', 'santé', 'public', 'lieux', 'diffuser', 'musique', 'amplifié', 'devoir', 'dépasser', 'niveau', 'moyen', 'db', 'minute', 'respecter']
# ['dette', 'relever', 'niveau', 'individuel', 'attribuer', 'solidairement', 'ensemble', 'membre', 'ménage', 'résultat', 'diffuser', 'indiquer', 'pourcentage', 'population', 'vivre', 'ménage', 'type', 'dette', 'considérés']
# ['physique', 'ingrat']
# ['grand', 'meaulnes', 'jeter', 'chapeau', 'terre', 'voir', 'cheveu', 'complètement', 'ras', 'paysan']
# ['économiste', 'japonais', 'ohmae', 'kenichi', 'invent', 'formule', 'commode', 'triade', 'décrire', 'polarisation', 'monde']
# ['étude', 'influence', 'chaîne', 'ramifier', 'court', 'métabolisme', 'xénobiotique', 'développer', 'party']
# ['manière', 'monde', 'construire', 'partir', 'grand', 'découverte', 'largement', 'responsable', 'géographie', 'contemporaine']
# ['subis', 'faire', 'subir', 'à', 'enfant', 'à', 'ose', 'affranchir', 'résume', 'inventeur', 'produit', 'ludique']
# ['devenir', 'courant', 'déplorer', 'france', 'acquérir', 'place', 'championne', 'europe', 'prélèvement', 'obligatoire', 'expression', 'englobe', 'impôt', 'état', 'impôt', 'local', 'taxe', 'cotisation', 'social', 'part']
# ['filet', 'savoir', 'empêcher', 'algue', 'atlantique', 'voguer', 'tirer', 'saveur', 'eau', 'traverser']
# ['fois', 'projet', 'abouti', 'liberté', 'harmonie', 'renaissance']
# ['vrai', 'pierre', 'livre', 'ami', 'meilleurs']
# ['copine', 'zoé']
# ['faire', 'simplement', 'illusion', 'monde', 'illusion', 'poétique', 'sentimental', 'joyeux', 'mélancolique', 'sale', 'lugubre', 'nature']
# ['déjeuner', 'face', 'face', 'regarder', 'sourire', 'cesse', 'occupé', 'uniquement', 'envelopper', 'charme', 'doux', 'tendresse', 'commencer']
# ['travaille', 'domaine', 'informatique']
# ['action', 'pouvoir', 'envisager', 'nonobster', 'doute', 'subsister', 'lien', 'causalité']
# ['pouvoir', 'montrer', 'père', 'exemple', 'destination', 'père', 'impliquer', 'faire', 'objet', 'curiosité', 'héros', 'absolu', 'faudrait', 'dresser', 'statue']
# ['norme', 'européen', 'absurde', 'étouffer']
# ['monsieur', 'cruchon', 'venir', 'donner', 'réponse', 'question']
# ['faire', 'vélo', 'parc', 'autour', 'citadelle', 'fortifier']
# ['travaille', 'ici', 'jour']
# ['chercher', 'point', 'assurance', 'fermeté']
# ['jeune', 'soumettre', 'impératif', 'moral', 'succès']
# ['jean', 'copine']
# ['sénateur', 'élu', 'scrutin', 'majoritaire', 'accepter', 'fonction', 'gouvernemental', 'remplacer', 'expiration', 'délai', 'mois', 'cessation', 'fonction', 'élire', 'temps']
# ['étymologie', 'latin', 'mot', 'travail', 'tripalium', 'signifier', 'instrument', 'torture']
# ['désagrément', 'esthétique', 'déchet', 'menacer', 'moitié', 'oiseau', 'marin', 'espèce', 'poisson', 'crustacée', 'mammifère', 'vivre', 'océan', 'confondre', 'déchet', 'nourriture']
# ['promettre', 'faire', 'découvrir', 'londres', 'visiter', 'musée', 'monument', 'parc']
# ['catherine', 'down', 'soulagement', 'traverser', 'épreuve', 'idée', 'partager', 'petit', 'studio', 'angoisser']
# ['savoir', 'ici', 'impavide', 'jument', 'étalon', 'pénètre', 'impavide', 'pourtant', 'ignorer', 'verge', 'étalon', 'digne', 'estime', 'sort', 'fourreau']
# ['enfant', 'envie', 'travailler', 'devoir', 'école']
# ['noter', 'apprentissage', 'grammaire', 'français', 'obéir', 'al', 'objectif', 'parfaitement', 'connaître', 'méthod', 'viable', 'apprendre', 'langue', 'étranger', 'immersion']
# ['remercier', 'voyager', 'compagnie', 'france', 'air']
# ['association', 'promotion', 'développement', 'apprentissage', 'ligne', 'note', 'calculatrice', 'supplanter', 'calcul', 'mental', 'y', 'opération', 'basique', 'utilisation', 'ordinateur', 'relier', 'internet', 'pouvoir', 'aisément', 'remplacer']
# ['créer', 'société', 'moderne', 'ruine', 'ancien', 'civilisation']
# ['laisserai', 'sortir', 'condition', 'jurer', 'solennellement', 'révéler', 'dormi', 'entrer', 'grotte', 'al', 'serpent', 'roi']
# ['bord', 'lac', 'vraiment', 'magnifique', 'faire', 'sport']
# ['joue', 'guitare', 'bar']
# ['intérieur', 'maison', 'y', 'grand', 'salon', 'table', 'chaise', 'accueillir', 'ami']
# ['bel', 'robe', 'moulant', 'vouloir', 'mettre', 'forme']
# ['indiquer', 'finir', 'film', 'hier', 'aller', 'commercer', 'semaine']
# ['révolution', 'français', 'déjà', 'cours', 'prise', 'symbolique', 'juillet', 'forteress', 'compter', 'prisonnier', 'époque', 'événement', 'clé', 'révolte']
# ['semaine', 'maison', 'blanche', 'courtiser', 'poignée', 'sénateur', 'républicain', 'démocrate', 'modérer', 'détenir', 'pouvoir', 'bloquer', 'sauver', 'grand', 'projet']
# ['petit', 'replet', 'hautainement', 'timide', 'ventre', 'légèrement', 'proéminent', 'surplomb', 'offrir', 'pent', 'ascendant', 'mettre', 'évidence', 'bouton', 'gilet', 'pantalon', 'marquer', 'milieu', 'exact', 'corps']
# ['individu', 'actif', 'volontaire', 'initiateur', 'reconversion']
# ['veux', 'regarde']
# ['mardi', 'aller', 'entraînement', 'football']
# ['vacance', 'approcher', 'aimerais', 'voir']
# ['vieux', 'acquiesça', 'tête', 'grand', 'cornette', 'ancien', 'mode', 'aile', 'recourber', 'enveloppaient', 'quasi', 'blanc', 'mousseline', 'empeser']
# ['fois']
# ['aller', 'chambre', 'devoir', 'monter', 'escalier']
# ['situation', 'chercher', 'facteur', 'maladie', 'bilan', 'taux', 'ferritine', 'test', 'pouvoir', 'judicieux']
# ['gouverneur', 'colonie', 'william', 'bradford', 'décider', 'proclamer', 'jour', 'remerciement', 'action', 'grâce', 'remercier', 'dieu', 'donner', 'terre', 'finalement', 'accueillant', 'indigène', 'serviable']
# ['centaine', 'caméra', 'automatique', 'installer', 'sol', 'français', 'surveiller', 'permanence', 'rentrée', 'météorite', 'atmosphère']
# ['lendemain', 'assistant', 'téléphoner', 'savoir', 'disponible', 'lundi']
# ['année', 'valéry', 'giscard', 'estaing', 'engager', 'europe', 'projet', 'constitution', 'européen', 'rejeter', 'france', 'référendum', 'emporte', 'largement']
# ['survivre', 'pervers', 'narcissique']
# ['cherche', 'travail', 'réceptionniste', 'hôtel']
# ['multiplicité', 'culture', 'condition', 'nécessaire', 'développement', 'humain', 'réussi', 'préservation', 'diversité', 'linguistique', 'essentielle', 'langue', 'écrire', 'oral', 'principal', 'mode', 'transmission', 'culture']
# ['aller', 'cuisine', 'boire', 'café']
# ['aller', 'aller', 'déjà', 'partir']
# ['immense', 'majorité', 'déchet', 'professionnel', 'mêlé', 'al', 'gravat', 'al', 'emballage', 'enterrer', 'sol', 'faut', 'isolé', 'vue', 'traitement', 'affirme', 't']
# ['y', 'restaurant']
# ['serveur', 'y', 't', 'problème', 'table']
# ['exception', 'paysage', 'audiovisuel', 'y', 'règle']
# ['sollicitation', 'incessant', 'auxquelle', 'confronter', 'obliger', 'discipline', 'fer', 'envahir', 'devient', 'nécessaire', 'établir', 'règle', 'limite']
# ['prompt', 'espérer', 'comte', 'p']
# ['raisonnement', 'mathématique', 'logique', 'masculin']
# ['chien', 'apprendre']
# ['crise', 'âge', 'adulte', 'choix', 'rationnel']
# ['chien', 'besoin', 'rencontrer', 'animal']
# ['paraître', 'manger', 'spécialité', 'île', 'fromage', 'chèvre']
# ['mari', 'éditeur']
# ['descendre', 'cheval', 'aller', 'long', 'noisetier', 'églantier', 'cheval', 'valet', 'écurie', 'rêne', 'aller', 'craquement', 'silence', 'torse', 'nu', 'soleil', 'midi', 'aller', 'sourire', 'étrange']
# ['habileté', 'plan', 'consister', 'point', 'émotion', 'charme', 'début', 'attachant', 'catastrophe', 'émouvante', 'groupement', 'adroit', 'petit', 'constant', 'dégager', 'sens', 'définitif', 'oeuvre']
# ['population', 'mondial', 'net', 'ralentissemer', 'augment', 'pouvoir', 'atteindre', 'milliard', 'plafonner', 'autour', 'milliard', 'fin', 'xxi', 'siècle']
# ['aller', 'cacher', 'coin', 'salon', 'groupe', 'homme', 'causer']
# ['oui', 'y', 'grand', 'armoir']
# ['y', 'mouvement', 'social', 'france', 'présence', 'jeune', 'étudiant', 'lycéen', 'déterminant']
# ['jour', 'seigneur', 'église', 'supprimer', 'révolution', 'vouer', 'gémonie', 'napoléon', 'prétexte', 'peuple', 'manger', 'dimanche', 'devoir', 'pouvoir', 'travailler', 'dimanche']
# ['chose', 'train', 'mal', 'tourner']
# ['parade', 'descendre', 'avenue', 'champs', 'élysée', 'place', 'étoile', 'alia', 'place', 'charlesdegaulle', 'place', 'concorde']
# ['devoir', 'travailler', 'plaire']
# ['emma', 'rêver', 'jour', 'mariage', 'revoir', 'milieu', 'blé', 'petit', 'sentier', 'marcher', 'église']
# ['flanc', 'noce', 'village', 'rumeur', 'bourdonner', 'essaim']
# ['ouvrir', 'porte', 'chat', 'entrer', 'empressement']
# ['heure', 'bureau', 'of', 'labor', 'statistics', 'ministère', 'fédéral', 'américain', 'travail', 'établir', 'français', 'produire', 'davantage', 'richesse', 'anglais', 'allemand', 'japonais']
# ['finie', 'façade', 'gris', 'terne', 'terminer', 'morosité', 'ambiant']
# ['lutter', 'philosophie', 'réflexion', 'hegel', 'devoir', 'entreprendre', 'lutte', 'philosophie', 'romantisme']
# ['réussir']
# ['vraiment', 'accord', 'monsieur']
# ['pouvoir', 'contenter', 'sentiment', 'liberté', 'déduire', 'existence']
# ['morin', 'mode', 'connaissance', 'parcelliser', 'prédire', 'ignorance', 'global']
# ['science', 'démarche', 'enseignant', 'intéresser', 'ressource', 'pédagogique', 'formation', 'main', 'pâte', 'démarche', 'volontaire']
# ['cachent', 'partie', 'douleur']
# ['finir', 'pâte', 'italien', 'gros', 'haricot', 'blancs', 'pomme', 'terre', 'robe', 'champ', 'beurre', 'bon', 'pain', 'frais']
# ['aime', 'lire', 'soir', 'dormir']
# ['aller']
# ['gifl', 'immatériel', 'ébauche', 'cruauté', 'petit', 'plain', 'pied', 'sexuel', 'indifférence', 'mâle']
# ['rocher', 'grand', 'masse', 'pierre', 'dur', 'enraciner', 'terre']
# ['manger', 'viand', 'végétarienne']
# ['bave', 'crapaud', 'atteindre', 'blanche', 'colombe']
# ['technique', 'émergente', 'finalisation', 'produire', 'endroit', 'presque', 'simultanément']
# ['professeur']
# ['falloir', 'aller', 'demander', 'société']
# ['aimer', 'plat', 'cantine']
# ['journaliste', 'poser', 'question', 'auxquelle', 'répondre', 'hésitation']
# ['âme', 'mobile', 'comtesse', 'embrasser', 'enthousiasme', 'idée', 'genre', 'vie', 'y', 'an', 'habiter', 'château', 'vénérable', 'élever', 'majestueusement', 'milieu', 'vieux', 'châtaignier', 'planter', 'temps']
# ['adulte', 'apprendre', 'breton', 'apprennent', 'enfant', 'digner', 'admiration']
# ['juillet', 'supprimer', 'eau', 'lait']
# ['association', 'défense', 'environnement', 'solidarité', 'social', 'mettre', 'garde', 'exclusion', 'obligation', 'rénovation', 'énergétique', 'logement', 'future', 'loi', 'climat']
# ['plaie', 'saigner', 'flanc', 'christ', 'contradiction', 'essentiel', 'raison', 'hegel', 'voie', 'piu', 'fois', 'biessure']
# ['exemple', 'privilégier', 'achat', 'patriotique', 'faible', 'empreindre', 'carbone']
# ['ajoute', 'hautemer', 'déstabilisateur', 'spéculation', 'matière']
# ['lucien', 'neuwirth', 'pionnier', 'contraception', 'mourir', 'nuit', 'lundi', 'mardi', 'an', 'suite', 'infection', 'pulmonaire', 'hôpital', 'rossini', 'saint', 'périne', 'pans']
# ['y', 'impossible', 'estime', 'député', 'pourcent', 'déplacement', 'domicil', 'travail', 'faire', 'kilomètre', 'pourcent', 'trajet', 'faire', 'voiture']
# ['travaille', 'hopital']
# ['préférer', 'rester', 'maison', 'profitent', 'temps', 'libre', 'visiter', 'famille', 'balader', 'ville']
# ['occuper', 'stagiaire', 'expliquer', 'fonctionnement', 'entreprise', 'règlement', 'intérieur']
# ['proposer', 'piste', 'résoudre', 'problème', 'préconiser', 'utilisation', 'objet', 'connecté', 'application', 'fonctionner', 'localement', 'suggérer', 'utilisation', 'table', 'consentement', 'définir', 'simplement', 'utilisateur', 'consentir']
# ['essayer', 'limiter', 'paire', 'chaussure']
# ['accostage', 'terminer', 'chaloupe', 'déverser', 'terre', 'myriade', 'poisson', 'étincelant', 'femme', 'empiler', 'mesure', 'corbeille', 'air', 'brasser', 'butin', 'barbare']
# ['photon', 'nécessaire', 'permettre', 'réduction', 'molécule', 'dioxyde', 'carbone', 'eau']
# ['engendre', 'mouvement', 'alternatif', 'réduire', 'transformation', 'mouvement', 'frottement', 'vibration', 'bruit']
# ['considéré', 'membre', 'famille', 'part', 'entier']
# ['oui', 'ouvrir', 'restaurant', 'lyon', 'mois', 'centre', 'ville']
# ['élu', 'arrondissement', 'coupe', 'budget', 'opéra', 'répondre', 'recommandation', 'récurrent', 'chambre', 'régional', 'compte', 'reprocher', 'impact', 'établissement', 'lyrique', 'finance', 'municipal']
# ['aller', 'présenter', 'famille']
# ['tourisme', 'cause', 'dégradation', 'environnement', 'désorganisation', 'société', 'traditionnel', 'voyageur', 'devoir', 'écoute', 'tolérer', 'adapter', 'vie', 'local']
# ['fille', 'bizarre']
# ['habite', 'new', 'york']
# ['accès', 'voie', 'électronique', 'ensemble', 'formalité', 'registre', 'commerce', 'société']
# ['falloir', 'compétence', 'technologie', 'fabriquer', 'utiliser', 'capsule', 'déjà', 'existant']
# ['ramper', 'plat', 'ventr', 'galoper', 'patte', 'prendre', 'panier', 'dent', 'tordre', 'glisser', 'ondulait', 'serpenter', 'mort', 'vider', 'giberne', 'cartouchière', 'singe', 'ouvrir', 'voix']
# ['habille', 'faire', 'partie', 'personnalité']
# ['vacance', 'relaxante']
# ['faudrait', 'aborder', 'question', 'tôt', 'prendre', 'mesure', 'coercitif', 'adéquate']
# ['grand', 'différence']
# ['occasion', 'écouter', 'chanson', 'moderne']
# ['bon', 'rapport', 'femme', 'père', 'lucrezia', 'guglielmo', 'cortigiani', 'note', 'appelant', 'douce', 'mère']
# ['détachement', 'procurer', 'statut', 'voyageur', 'facilite', 't', 'transgression', 'norme', 'légal', 'moral', 'auxquelle', 'individu', 'domicile', 'fixe']
# ['aime', 'faire', 'parapente']
# ['école', 'pouvoir', 'faire']
# ['voir', 'pleurer', 'évanouir', 'émotion', 'grand']
# ['répondre', 'bonté', 'donner', 'conseil', 'affectueux', 'offrir', 'amitié', 'sincère', 'déclara', 'comte', 'p', 'pouvoir', 'recevoir']
# ['vraiment']
# ['vien', 'ici']
# ['annoncer', 'aller', 'faire', 'appel']
# ['perdre', 'feuille']
# ['dani', 'inscrit', 'concours', 'administratif']
# ['limoges', 'grand', 'ville', 'voir', 'paris']
# ['précieux', 'instrument', 'origine', 'américain', 'envoyer', 'gêner', 'projectile', 'conique', 'kilogramme', 'distance', 'moyenne', 'kilomètre']
# ['taire', 'ridicule']
# ['choisir', 'logement', 'évident', 'acheter', 'appartement', 'ville', 'préférer', 'maison', 'campagne']
# ['internationalisation', 'marché', 'financier', 'diffusion', 'information', 'média', 'électronique', 'avatar', 'mondialisation', 'intensifier', 'menace', 'peser', 'déjà', 'petit', 'langue']
# ['changer', 'vraiment', 'favoriser', 'accès', 'connaissance']
# ['branche', 'complètement', 'nu', 'tandis', 'feuille', 'tomber', 'terre']
# ['inattention', 'augmenter', 'désir', 'captiver', 'attention', 'intéresser', 'plair', 'remplira', 'sentiment', 'confus', 'respect']
# ['poursuivre', 'sorte', 'lever', 'objection', 'retourner', 'manière', 'raisonnement', 'plaider', 'faveur']
# ['commerce', 'équitable', 'réduire', 'délibérément', 'forme', 'politique', 'social', 'libéralisme', 'faire', 'prévaloir', 'oeuvre', 'caritatif', 'droit', 'social', 'contraire', 'véritable', 'enjeu', 'société']
# ['trouve']
# ['idée']
# ['jour']
# ['conscience', 'malheureux', 'mauvais', 'infini', 'philosophie', 'fichte', 'amène', 'concevoir']
# ['langue', 'employer', 'internet', 'existe', 'monde', 'moderne']
# ['boire', 'tasse', 'café', 'falloir', 'faire', 'pousser', 'plan', 'café', 'récolter', 'transporter', 'emballer', 'vendre', 'préparer']
# ['stratégie', 'sauvegarde', 'donnée', 'constitue', 'pierre', 'angulaire', 'plan', 'continuité', 'reprise', 'aller', 'permettre', 'assurer', 'critère', 'disponibilité']
# ['vouloir', 'trouver', 'cadeau', 'anniversaire', 'copine', 'aller', 'aller', 'centre', 'commercial']
# ['ciel', 'noir']
# ['aimer', 'ferme', 'fenêtre', 'partir']
# ['républicain', 'outrer', 'ancien', 'commentaire', 'viser', 'nommément', 'tandis', 'progressiste', 'bernie', 'sanders', 'jugeaient', 'centriste']
# ['gauche', 'salle', 'bain', 'vue', 'jardin', 'sens', 'maison']
# ['acteur', 'marque', 'max', 'havelaar', 'croire', 'feignent', 'croire', 'disposer', 'rapport', 'force', 'nécessaire', 'infléchir', 'pratique', 'multinationale', 'droit']
# ['travaille', 'rome']
# ['débattais', 'intérieuremer', 'indigner']
# ['temps', 'réaliser', 'bénéfice', 'piero', 'acheter', 'plaque', 'décorer', 'coeur', 'transpercer', 'flèche', 'donner', 'paysan']
# ['pouvoir', 'jouer', 'jules', 'alice']
# ['activité', 'apparer', 'religion', 'grec', 'antiquité', 'cadeau', 'imposer', 'homme', 'pouvoir', 'survivre']
# ['alexandre', 'aimait', 'réviser', 'université', 'flirter', 'fille', 'faculté', 'droit']
# ['moment', 'démocratie', 'devoir', 'écouter', 'peuple']
# ['revanche', 'sapin', 'perdu', 'aiguille']
# ['aime', 'reproche', 'susceptible']
# ['y', 'région', 'enfant', 'aller', 'école', 'mercredi']
# ['midi', 'quize', 'minute']
# ['participer', 'construction', 'canal']
# ['adore', 'cuisine', 'ici']
# ['poser', 'courrier', 'table']
# ['faire', 'manger', 'jardin', 'ami', 'voisin', 'savoir']
# ['société', 'évolué', 'école', 'y', 'jeune', 'décrit', 'mlle', 'lesueur']
# ['taire', 'vien']
# ['aime', 'photo']
# ['grandmère', 'paternel', 'céramiste', 'léonard', 'pouvoir', 'initia', 'art']
# ['installer', 'maison', 'vacance', 'prendre', 'apéritif', 'voisin']
# ['croire', 'faire', 'plaisir']
# ['chiffre', 'susceptible', 'varier', 'cours', 'année']
# ['résultat', 'étude', 'démontrer', 'bon', 'santé', 'mener', 'train', 'vie', 'normal', 'valeur', 'ferritine', 'influencer', 'degré', 'fatigue']
# ['fenêtre', 'refermer', 'main', 'faire', 'mal']
# ['restaurant', 'loin', 'musée', 'louvre']
# ['liberté', 'priver', 'ordre', 'public', 'équation', 'fétiche', 'français']
# ['vouloir', 'aller', 'montagne']
# ['commencer', 'petitdéjeuner', 'café', 'arc', 'triomphe', 'croissant', 'délicieux']
# ['inversement', 'région', 'tempérer', 'lointain', 'intéresser', 'médiocrement', 'colonisateur', 'explosion', 'démographique', 'vieux', 'continent', 'xix', 'siècle', 'moment', 'pays', 'devenir', 'prolongement', 'européen']
# ['gourmet', 'adepte', 'bistronomie', 'voir', 'proposer', 'plateau', 'accompagner', 'fruit', 'secs', 'voire', 'confiture', 'mélange', 'sucrer', 'saler', 'sied', 'parfaitement', 'al', 'apéritif', 'dinatoire', 'al']
# ['héritier', 'héritier', 'recevoir', 'droit', 'patrimoine', 'mort']
# ['appelle', 'jessica']
# ['remercier', 'souhaite', 'bon', 'journée']
# ['pouvoir', 'citer', 'action', 'condamnable', 'pouvoir', 'contester', 'annoncer', 'générosité', 'dévouement', 'homme', 'immoral', 'homme', 'sûr', 'épithète', 'heureusement', 'inventer', 'insinuer', 'ignore', 'deviner', 'savoir']
# ['devoir', 'couper', 'ongle']
# ['distanciation', 'social', 'occasion', 'réunir', 'également', 'fréquent']
# ['dessein', 'plaire', 'mettre', 'vie', 'intérêt', 'animer', 'existence', 'manière', 'inusitée']
# ['père', 'côté', 'méséglise', 'bel', 'vue', 'plaine', 'connaître', 'côté', 'guermante', 'type', 'paysage', 'rivière', 'donnai', 'concevoir', 'entité', 'cohésion', 'unité', 'appartenir', 'création', 'esprit']
# ['vouloir', 'attendre', 'bar', 'appeler', 'prêt']
# ['emballage', 'innovant', 'allier', 'développemer', 'ligne', 'chemin', 'fer', 'permettre', 'distribution', 'camembert', 'région', 'france', 'étranger']
# ['vie', 'composer', 'chose', 'imprévu', 'contraire', 'disparate', 'brutal', 'suite', 'chaîne', 'pleine', 'catastrophe', 'inexplicable', 'illogique', 'contradictoire', 'devoir', 'classer', 'chapitre']
# ['regarde', 'télévision']
# ['démon', 'vouloir', 'trouver', 'cachette', 'revoir', 'méchant', 'femme']
# ['dénoncer', 'discrimination', 'collectivement', 'accepter', 'difficile']
# ['déjà', 'train', 'sortir', 'lit']
# ['église', 'animer']
# ['métier', 'aller', 'disparaître', 'apparaître']
# ['révolution', 'manifeste', 'vie', 'quotidien']
# ['basque', 'égyptien', 'chinois', 'grec', 'hébreu', 'latin', 'persan', 'sanskrit', 'tamoul', 'souffler', 'bougie']
# ['long', 'expérience', 'grand', 'nombre', 'restaurant', 'restauration', 'collectif']
# ['apprendre', 'hervé', 'brassier', 'pouvoir', 'heure', 'chien', 'guid', 'indigo']
# ['seigneur', 'infernal', 'attire', 'sourire', 'dangereux', 'trouble']
# ['existence', 'divin', 'prouver', 'pouvoir', 'rester', 'sceptique', 'origine', 'travail', 'relater', 'précédemment']
# ['rappel', 'massacre', 'million', 'bison', 'orchestrer', 'fin', 'xix', 'siècle', 'venir', 'bout', 'peau', 'rouge']
# ['suen', 'liebowitz', 'éloquents', 'dispersion', 'variété', 'mode', 'mesure', 'type', 'cours', 'entreprise']
# ['égout', 'soufflaient', 'bouche', 'granit', 'haleine', 'empester', 'cuisine', 'souterraine', 'jeter', 'rue', 'fenêtre', 'miasme', 'infâme', 'eau', 'vaisselle', 'vieux', 'sauce']
# ['regarde']
# ['grand', 'déception', 'pouvoir', 'accueillir', 'zurich']
# ['nord', 'forêt', 'sud', 'haute', 'montagne', 'séparer', 'presque', 'entièrement', 'monde']
# ['y', 'voiture', 'y', 'embouteillage']
# ['entreprise', 'refuser', 'systématiquement', 'quinquagénaire', 'insurge', 'danièle', 'lepeu', 'diriger', 'agence', 'seniors', 'société', 'travail', 'temporaire', 'adecco', 'boulogne', 'billancourt']
# ['soir', 'perdre', 'puissance']
# ['y', 'film', 'acteur', 'préféré']
# ['mère', 'exceptionnellement', 'boire', 'vin', 'chaud', 'normalement', 'droit']
# ['peur', 'vraiment', 'question', 'feeling']
# ['hocher', 'tête', 'doucement', 'regarder', 'avion']
# ['tonne', 'couche', 'usager', 'jeter', 'année', 'japon', 'représente', 'pourcent', 'déchet', 'incinérer', 'commune']
# ['centre', 'ville', 'y', 'joli', 'quartier', 'magasins', 'chic', 'bon', 'restaurant']
# ['bonjour', 'passeport', 'billet', 'plaire']
# ['donnée', 'indiquer', 'problème', 'malnutrition', 'devenir', 'complexe', 'stratégie', 'lutte', 'pays', 'organisation', 'international', 'devoir', 'attaquer', 'triple', 'fardeau', 'peser', 'pays', 'développement', 'maladie', 'infectieux']
# ['désert', 'déplacement', 'effectuer', 'tôt', 'matin', 'heure', 'profiter', 'fraîcheur', 'persistant', 'nuit']
# ['attendre', 'arrivée']
# ['ressource', 'disponible', 'ligne', 'pouvoir', 'faciliter', 'apprentissage', 'lycéen']
# ['renonce', 'jamais', 'al', 'cruauté', 'vivifier', 'passion', 'redonner', 'lustre']
# ['fatiguer', 'décide', 'marcher', 'dame', 'garde']
# ['habitant', 'quartier', 'historique', 'vie', 'rue', 'touriste', 'perdre', 'magasin', 'quartier']
# ['dison', 'coopération', 'faire', 'partie', 'arsenal', 'pédagogique', 'élève']
# ['eus', 'sortir', 'abat', 'congeler', 'frigo', 'hier', 'soir', 'température', 'ambianter', 'repas', 'midi']
# ['satisfait', 'travail']
# ['virginie', 'adore', 'vacance', 'mer']
# ['déjà', 'prendre', 'avion', 'aller', 'rome', 'italie', 'y', 'an']
# ['balle', 'faire', 'étinceler', 'pavé', 'côté']
# ['épicerie', 'quartier', 'ouvrir', 'jour', 'conger', 'indiquer', 'panneau', 'informatif', 'acheter', 'lait', 'sirop', 'érable', 'préparer', 'pain', 'perdu', 'al', 'enfant']
# ['mise', 'tension', 'ordinateur', 'exécut', 'instruction', 'faire', 'lire', 'manipuler', 'réécrire', 'ensemble', 'donnée', 'déterminer', 'mémoire', 'mort', 'amorçage']
# ['an']
# ['étude', 'montre', 'vaccin', 'offrir', 'taux', 'protection', 'élevé', 'permettre', 'éviter', 'hospitalisation']
# ['temps', 'idée', 'mode', 'critère', 'comportement', 'social', 'emprunter', 'france', 'aller', 'façonner', 'société', 'policer', 'europe', 'continental', 'mesure', 'angleterre']
# ['prendre', 'pseudonyme', 'masculin', 'poursuivre', 'travail', 'revisiter', 'y', 'montrer', 'imaginer', 'prémisse', 'travail', 'poincaré']
# ['désolé', 'retard', 'occupé', 'soir']
# ['aller', 'voir', 'film', 'humour', 'air', 'petit', 'copain']
# ...
# ['cas', 'également', 'ong', 'dizaine', 'pays', 'viennent', 'aide', 'al', 'enfant', 'soldat', 'assurer', 'protection', 'garantissant', 'suivi', 'médical', 'scolarisation']
# ['aimerais', 'continuer', 'étude', 'lycer', 'université', 'pouvoir']
# ['aller', 'lutter', 'fake', 'news', 'faux', 'troubler', 'jugement', 'honnête', 'citoyen', 'point', 'pousser', 'bras', 'affreux', 'populiste', 'méchant', 'donald', 'trump', 'infâme', 'brexiter', 'manche']
# ['voisin']
# ['invincible', 'sommeil', 'saisir', 'bientôt', 'atroce', 'réveil']
# ['grand', 'bretagne', 'suède', 'finlande', 'allemagne', 'établissement', 'séparer', 'fille', 'garçon', 'matière', 'scientifique', 'sexe', 'féminin', 'sousreprésenter']
# ['contrainte', 'aller', 'mettre', 'terme', 'développemer', 'trottinette']
# ['joli']
# ['grand', 'occasion', 'accomplir', 'voyage', 'politique', 'marquis', 'remettre', 'fils', 'écu', 'usage', 'donner', 'femme', 'menait']
# ['content', 'vois']
# ['comprendre', 'manière', 'composer', 'ancien', 'procédé', 'visible', 'oeil', 'déroute', 'critique', 'découvrir', 'fils', 'secret', 'presque', 'invisible', 'employer', 'artiste', 'moderne', 'place', 'ficelle', 'nom']
# ['réveiller', 'entendre', 'bruit', 'étrange', 'ouvrir', 'oeil', 'voir', 'serpent', 'réveiller']
# ['descarte', 'liberté', 'indifférence', 'considérée', 'degrer', 'liberté', 'témoigne', 'temps', 'libre', 'arbitre', 'apparente', 'homme', 'dieu', 'méditation']
# ['nombre', 'auteur', 'polar', 'thriller', 'persister', 'tourner', 'ad', 'nauseam', 'autour', 'disparition', 'enfant', 'sévice', 'infliger', 'tueur', 'série', 'poignée', 'efforcer', 'combler', 'angle', 'mort']
# ['jeune', 'femme', 'avancer', 'jeter', 'bourse', 'écuyer', 'vert']
# ['part', 'faire', 'sport', 'fois', 'semaine']
# ['waf', 'waf', 'vouloir', 'rentrer', 'maison', 'alice']
# ['minute']
# ['concentré', 'année', 'résultat', 'scolaire', 'enfant', 'parent', 'prêt', 'bain', 'mer', 'soleil', 'délaver', 'table', 'multiplication', 'parfaire', 'indicatif', 'théorème', 'géométrie', 'chèremer', 'acquérir']
# ['maison', 'venir', 'vendre', 'hollandais']
# ['point']
# ['aim', 'courir', 'pluie']
# ['auteur', 'lu', 'grammaire', 'impertinent', 'propose', 'jeu', 'lire', 'vite']
# ['aller', 'bientôt', 'grand', 'surprise']
# ['protestataire', 'continuer', 'descendre', 'rue', 'demander', 'départ', 'général', 'putschiste', 'libération', 'centaine', 'détenu', 'emprisonner', 'semaine']
# ['y', 'nuage', 'pluie', 'carte', 'aller', 'pleuvoir', 'y', 'risque', 'tempête', 'grêle']
# ['trajet', 'bus', 'heureux', 'retrouver', 'mer']
# ['lait', 'collecté', 'roquefort', 'délimiter', 'territoire', 'rayon', 'kilomètre', 'autour', 'village', 'roquefortsursoulzon', 'situer', 'aveyron', 'part', 'roquefort']
# ['abattage', 'tiers', 'troupeau', 'yellowstone', 'hiver', 'éleveur', 'bétail', 'montana', 'meurtrir', 'tribu', 'indien']
# ['commémoration', 'fête', 'anniversaire', 'fin', 'second', 'guerre', 'mondial']
# ['prêt', 'entrer', 'histoire']
# ['grand', 'parent', 'enfant', 'aiment', 'passer', 'temps', 'vacance']
# ['donner', 'chance', 'al', 'documentaire', 'faire', 'exister', 'salle', 'mission', 'temps', 'normal', 'association', 'documentaire', 'grand', 'écran', 'créer']
# ['fai', 'devoir']
# ['retrouve', 'situation', 'redouter', 'gouvernement', 'transforme', 'mesure', 'satisfaire', 'intérêt', 'économique']
# ['pourcent', 'femme', 'an', 'résider', 'france', 'métropolitain', 'déclarent', 'pratiquer', 'activité', 'physique', 'sportif', 'mois', 'pourcent', 'homme']
# ['monde', 'anglais']
# ['faire', 'partie', 'vie', 'social']
# ['faire', 'aprèsmidi', 'chill', 'mode', 'lectur', 'chat', 'canapé']
# ['éric', 'aller', 'éloigner', 'fur', 'mesure', 'elsa', 'mettre', 'doute', 'danger']
# ['ensuite', 'dîner', 'restaurer', 'soir', 'rentrer', 'maison']
# ['justement', 'tenter', 'faire', 'association', 'prévention', 'effectuer', 'travail', 'long', 'haleine']
# ['piscine', 'partager', 'exemple', 'genre', 'chose', 'bof']
# ['y']
# ['considérant', 'droit', 'humain', 'violer', 'pays', 'refuser', 'signer', 'protocole', 'kyoto', 'etat', 'unis', 'tête', 'inuit', 'songer', 'emprunter', 'voie', 'juridique', 'invoquer', 'déclaration', 'droit']
# ['croire', 'raison']
# ['membre', 'nombre', 'haut']
# ['manger', 'pomme']
# ['curé', 'posséder', 'également', 'âne', 'solide', 'obstiner', 'falloir', 'doux', 'faire', 'besogne']
# ['envoyer', 'manuscrit', 'poste', 'éditeur', 'refusent']
# ['attends', 'cherche']
# ['fois', 'trentetrois', 'jour', 'fureur', 'fabrice', 'comprendre', 'fin', 'mot', 'arriver']
# ['malnutrition', 'frappe', 'devoir', 'contribuer', 'nourrir', 'concitoyen', 'million', 'paysan', 'pauvre', 'victime', 'baisse', 'prix', 'dicter', 'libéralisation', 'échange', 'devoir', 'amputer', 'réserve', 'autoconsommation', 'renouveler']
# ['producteur', 'devoir', 'prendre', 'charge', 'uniquement', 'déchet', 'appareil', 'vendre', 'partir', 'août']
# ['marché', 'loin', 'maison', 'pouvoir', 'y', 'aller', 'pied']
# ['durer', 'an', 'jour']
# ['circuit']
# ['femme', 'admirer', 'époque']
# ['projet', 'an']
# ['contracter', 'conversation', 'femme', 'développer', 'idée', 'insurmontable', 'aversion', 'maxime', 'commune', 'formule', 'dogmatique']
# ['quell', 'bel', 'qualité', 'femme', 'azaël']
# ['téléphone', 'paris']
# ['diversité', 'linguistique', 'malheureusement', 'bénéficier', 'publicité']
# ['auteur', 'exploiter', 'terrain', 'erik', 'orsenna', 'chevalier', 'subjonctif', 'sortir', 'automne', 'monde', 'éducation', 'numéro', 'septembre']
# ['société', 'français', 'jamais', 'demander', 'accompagner', 'vieillissement', 'inexorable', 'population', 'analyse', 'patrice', 'leclerc', 'fondation', 'france']
# ['nonobster', 'conseil', 'professeur', 'aller', 'arrêter', 'étude']
# ['falloir', 'prendre', 'mesure', 'bouleversement', 'repenser', 'contenu', 'scolaire', 'manière', 'enseigner', 'apprendre']
# ['gagne', 'suffisamment', 'argent', 'voyager', 'europe', 'vagabond']
# ['venir', 'prétexte', 'malade']
# ['partie', 'énergie', 'fourni', 'déplacer', 'transformer', 'chaleur']
# ['année', 'réticer', 'fête', 'parent', 'enseignant', 'y', 'voir', 'fête', 'commercial']
# ['attendre']
# ['entendre', 'coup', 'scène', 'roulement', 'timbale', 'commença', 'instrument', 'cuivre', 'plaquer', 'accord', 'rideau', 'lever', 'découvrir', 'paysage']
# ['aller']
# ['ramper', 'serpent', 'fendre', 'air', 'hippogriffe']
# ['massant', 'soulager', 'douleur']
# ['écouter', 'cri', 'allégresse', 'monter', 'ville', 'rieux', 'souvenir', 'allégresse', 'menacer']
# ['aller', 'loin', 'envie', 'écouter', 'histoire', 'invite', 'fortement', 'lire']
# ['député', 'respecter', 'électeur', 'démissionner']
# ['exemple', 'matin', 'pler', 'arbre', 'repeupler', 'forêt', 'midi', 'libre', 'visiter', 'souhaite', 'reposer', 'plage']
# ['vouloir', 'préserver', 'petit', 'secteur', 'activité', 'continuer', 'écouler', 'produit', 'qualifié', 'équitable', 'pouvoir', 'comprendre']
# ['phénomène', 'autant', 'inquiétant', 'fois', 'produire']
# ['occasion', 'manifestation', 'déroule', 'pays', 'organisateur', 'commander', 'sondage']
# ['jour', 'trouver', 'parade', 'virus', 'épouvantable']
# ['bel', 'organe', 'imperturbable', 'aplomb', 'tempérament', 'intelligence', 'emphase', 'lyrisme', 'achevaient', 'rehausser', 'admirable', 'nature', 'charlatan', 'y', 'coiffeur', 'toréador']
# ['changer', 'tempo', 'marseillais', 'déplacer', 'défilé', 'jullet', 'bastille', 'invite', 'diner', 'salon', 'français']
# ['casser']
# ['peinture', 'dessin', 'pot']
# ['partie', 'vacance']
# ['cadre', 'aujourd', 'quittent', 'entreprise', 'ouvrir', 'maison', 'hôte']
# ['origine', 'politique', 'sens', 'moderne', 'mot', 'europe', 'clair', 'parvenir', 'idée', 'europe', 'partir', 'notion', 'équilibre', 'européen']
# ['vite', 'envie', 'partir', 'voyage', 'moyen']
# ['romancier', 'contraire', 'prétendre', 'donner', 'image', 'exacte', 'vie', 'devoir', 'éviter', 'soin', 'enchaînement', 'événement', 'paraîtrait', 'exceptionnel']
# ['apercevoir', 'erreur', 'rougir']
# ['pousser', 'long', 'soupir', 'joie', 'causer', 'presque', 'tranquillement', 'allure', 'intimité', 'connaître', 'an']
# ['famille', 'continuer', 'voient', 'diminuer', 'nombre', 'interlocuteur', 'domaine', 'usage', 'rétrécir', 'aboutir', 'création', 'dialecte', 'familial']
# ['rencontrer', 'françois', 'visite', 'calais']
# ['trentenaire', 'prendre', 'place', 'mosaïque', 'petit', 'écran']
# ['écart', 'demeur', 'homme', 'jeune']
# ['enfant', 'adorer', 'fête', 'manger', 'crêpe']
# ['magnifiquer', 'texte', 'beal']
# ['timide', 'irriter', 'plaindre', 'emportais', 'accabler', 'ellénore', 'reproche']
# ['prévoir', 'plantation', 'forêt', 'déductible', 'émission', 'gaz', 'serre', 'ges', 'arbre', 'croître', 'pomper', 'gaz', 'carbonique', 'air']
# ['environnement', 'pharmaceutique', 'international', 'durcir']
# ['face', 'problème', 'social', 'préconise', 'réduire', 'temps', 'travail', 'repenser', 'distribution', 'richesse', 'autremer', 'base', 'production', 'développer', 'davantage', 'appeler', 'tiers', 'secteur', 'économie', 'social']
# ['petit', 'chat']
# ['bonjour']
# ['fille', 'classe', 'y', 'mode', 'intéresse', 'histoire', 'garçon']
# ['vraiment', 'content', 'acccepter', 'invitation']
# ['friendly', 'amicalement', 'simplement', 'nonsens']
# ['fondateur', 'aristide', 'finet', 'donner', 'fille', 'désirer', 'commis', 'hauchecorn', 'baudu', 'débarquer', 'rue', 'michodière', 'franc', 'poche', 'épouser', 'fille', 'père', 'hauchecorn', 'élisabeth', 'entendre']
# ['jeune', 'future', 'comédien', 'développe', 'fort', 'intérêt', 'histoire', 'déguisement']
# ['accent', 'harmonieux', 'schleiermacher', 'pieux', 'virtuosité', 'tieck', 'ironie', 'schlegel', 'hegel', 'discerne', 'aisémer', 'tourment', 'esprit']
# ['question', 'poser', 'insistance', 'autorité', 'politique', 'sanitaire', 'semaine']
# ['naître', 'association', 'éco', 'cocotte']
# ['burette', 'encre', 'plume', 'médecin', 'servir', 'libeller', 'ordonnance', 'table']
# ['mort', 'dieu', 'donne', 'signification', 'souf', 'france', 'humaine', 'souffrance', 'humain', 'douleur', 'infini', 'preuve', 'infinité', 'divin', 'unir', 'contraire', 'esprit', 'humain', 'diviser']
# ['évaluation', 'atteindre', 'million', 'million', 'pays', 'développement']
# ['matin', 'même', 'routine', 'commencer', 'laver', 'visage', 'prendre', 'douche']
# ['parbleu']
# ['pouvoir', 'faire']
# ['taire', 'penser', 'envoyer', 'message', 'excuse', 'correspondre', 'étranger']
# ['confrère', 'curé', 'fort', 'jaloux', 'influence', 'détestaient', 'marquis', 'del', 'dongo', 'méprisait', 'simplement', 'raisonner', 'homme', 'étage']
# ['savoir', 'faire', 'jeune']
# ['enseignement', 'scolaire', 'créer', 'lien', 'matière', 'égard', 'apprentissage', 'code', 'périscolaire', 'limitatif']
# ['faire', 'ken', 'follett', 'offrir', 'intégralité', 'droit', 'auteur', 'récit', 'dame', 'publier', 'incendie', 'dame', 'paris', 'avril', 'fondation', 'patrimoine', 'fdp']
# ['voir', 'arriver', 'alenti', 'sucer', 'lèvre', 'crisper', 'court', 'pipe', 'terre', 'brun', 'secouer', 'cendre', 'pouce']
# ['walter', 'white', 'professeur', 'chimie', 'lycée', 'voir', 'fils', 'handicapé', 'moteur', 'femme', 'enceint', 'albuquerque', 'mexique']
# ['cerveau', 'seau', 'plagejouent', 'vase', 'communicant']
# ['prendre', 'train', 'dimanche', 'matin']
# ['revoir']
# ['phénomène', 'poursuivre', 'sociologue', 'résulte', 'fois', 'crise', 'emploi', 'encourager', 'mobile', 'bouleversement', 'valeur', 'cimenter', 'société', 'année', 'projet', 'vie', 'individu', 'construire', 'partir', 'catégorie']
# ['viens', 'installer']
# ['devoir', 'argent', 'ami', 'cause', 'défi']
# ['introduire', 'siège', 'vacant', 'soufflant', 'asseoir']
# ['chaos', 'ensuivre', 'candélabre', 'branche', 'symbole', 'lumière', 'spirituel', 'renverser']
# ['donne', 'faim']
# ['reposer', 'bu', 'verre', 'terrasse']
# ['trouve', 'différence', 'concerne', 'compréhension', 'concepts', 'abstraire', 'résolution', 'problème', 'complexe']
# ['demain', 'aller', 'faire', 'course']
# ['accueillir']
# ['force', 'livre', 'marie', 'ndiay', 'réside', 'frontière', 'indéterminer', 'réalisme', 'onirisme']
# ['chiffre', 'prouvent', 'fille', 'représenter', 'pourcent', 'effectif', 's', 'pourcent', 'série', 'littéraire', 'pourcent', 'école', 'ingénieur', 'pourcent', 'polytechnique']
# ['héros', 'mourait', 'héroiquement', 'suite', 'blessure', 'fin', 'film']
# ['langue', 'système', 'signe', 'constituer', 'lexique', 'construire', 'énoncé']
# ['faire', 'valise', 'énergiquement', 'vint', 'rencontre', 'empressement', 'détermination']
# ['année', 'pouvoir', 'acheter', 'matériel', 'professionnel', 'prix', 'nouveauté', 'année', 'pouvoir', 'classe', 'chef']
# ['facteur', 'faible', 'médiatisation', 'sport', 'féminin', 'pourcent', 'volume', 'horaire', 'retransmission', 'sportif', 'télévisuelle', 'chiffre', 'conseil', 'supérieur', 'audiovisuel', 'csa', 'citer', 'étude']
# ['usine', 'situer', 'mattighofen', 'nord', 'salzbourg']
# ['faire', 'promener', 'long', 'seine']
# ['faire', 'semaine', 'navire', 'immobiliser', 'accidentellement', 'récif', 'rocher', 'mer', 'île']
# ['excusez', 'perdu']
# ['diner', 'arthur', 'donner', 'petit', 'friandise', 'ressortir', 'assoupissais', 'tranquillement', 'panier']
# ['moto', 'devint', 'marque', 'distinctif', 'liberté', 'quelquefois', 'contestation']
# ['commerce', 'international', 'main', 'marché', 'libéral', 'permettre', 'paysan', 'al', 'artisans', 'sud', 'vivre', 'dignement', 'travail']
# ['pouvoir', 'imaginer', 'fromage', 'pouvoir', 'figurer', 'plateau', 'fromage', 'typ']
# ['souhaite', 'bon', 'année', 'pleine', 'bonheur', 'joie', 'bbonne', 'continuation', 'bachy', 'message']
# ['serge', 'papa', 'voyage', 'demain']
# ['force', 'ordre', 'tirer', 'gaz', 'lacrymogène', 'munition', 'caoutchouc', 'balle', 'réel', 'secouriste']
# []
# ['jour', 'comprendre']
# ['faire', 'grand', 'fête', 'année']
# ['projet', 'loi', 'climat', 'reprendre', 'proposition', 'convention', 'citoyen', 'débattre', 'assemblée', 'fin', 'mars', 'commission', 'spécial', 'lundi']
# ['ordonne', 'taire']
# ['période', 'favorable', 'an', 'an', 'capacité', 'apprentissage', 'langue', 'fort']
# ['pâques', 'parent', 'cacher', 'oeuf', 'chocolat', 'maison', 'jardin', 'enfant', 'amuser', 'chercher']
# ['appareil', 'pouvoir', 'recycler', 'pourcent', 'poids', 'enjeu', 'important']
# ['cruel', 'paradox']
# ['parent', 'habiter', 'immeuble']
# ['an', 'fidélité', 'inspirer', 'monsieur', 'p', 'confiance', 'entier', 'ellénore', 'grand', 'liberté']
# ['voir', 'fort', 'remous', 'briser', 'encablure', 'nappe', 'liquide', 'eussent', 'violemment', 'battu']
# ['couche', 'bon', 'heure']
# ['taire', 'porter', 'robe', 'soie', 'bleu', 'cousue']
# ['campagne', 'communication', 'grand', 'public', 'aller', 'également', 'mener']
# ['week', 'end', 'début', 'polémique', 'émerger', 'sousutilisation', 'vaccin', 'astrazeneca']
# ['applicatif', 'long', 'terme', 'portent', 'conception', 'poche', 'perfusion', 'sélection', 'bande', 'contention', 'optimisation', 'ampoule', 'injectable']
# ['faim']
# ['soirée', 'étudianter', 'thème', 'halloween', 'organiser', 'année']
# ['aller', 'donner', 'traitement', 'aller', 'aider']
# []
# ['presse', 'solidarité', 'européen', 'matière', 'vaccination', 'effondre']
# ['professeur', 'duquesnes']
# ['meilleur', 'methode', 'apprentissage', 'langue', 'etrangere']
# ['histoire', 'bon', 'année']
# ['marche', 'casser', 'tomber', 'terre']
# ['village', 'situer', 'micôte', 'cacher', 'grand', 'arbre', 'sommet', 'arbre', 'élever', 'architecture', 'charmant', 'joli', 'clocher']
# ['réduction', 'dioxyde', 'carbone', 'eau', 'nécessite', 'apport', 'énergie', 'élevé']
# ['connaître', 'présent', 'petitesse', 'passion', 'art', 'exagérer']
# ['décider', 'remplacer', 'habituel', 'porte', 'automatique', 'portier', 'superbe', 'livrer', 'donner', 'caractère', 'luxueux', 'aéroport']
# ['pâleur', 'splendide', 'donner', 'chose', 'majesté', 'marbre', 'al', 'race', 'ardenter', 'midi']
# ['samedi', 'mois', 'venir', 'rencontrer', 'conducteur', 'train']
# ['coût', 'lier', 'journalisation', 'négligeable', 'capacité', 'mémoir', 'journal', 'infini', 'administrateur', 'système', 'responsable', 'sécurité', 'intérêt', 'indentifier', 'événement', 'pertinent']
# ['sable', 'mer', 'haleter', 'respiration', 'rapide', 'étouffée', 'petit', 'vague']

# %%
# Word embedding 
### Parameters: 
#     - min_count: minimum number of occurence of single word in corpus to be taken into account
#     - size: dimension of the vectors representing the tokens
#     - IMPORTANT: processed_texts must be a list of lists of tokens object!
word2vec = Word2Vec(processed_texts, min_count=2, size=100)
vocab = word2vec.wv.vocab
print(vocab)
# Out:
# {'coût': <gensim.models.keyedvectors.Vocab object at 0x7fed89b82250>, 'kilométrique': <gensim.models.keyedvectors.Vocab object at 0x7fed89b825d0>, 'réel': <gensim.models.keyedvectors.Vocab object at 0x7fed89b82e90>, 'pouvoir': <gensim.models.keyedvectors.Vocab object at 0x7fed89b82f50>, 'valeur': <gensim.models.keyedvectors.Vocab object at 0x7fed89b82790>, 'moyenner': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c3d0>, 'fonction': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cd10>, 'moyen': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c490>, 'transport': <gensim.models.keyedvectors.Vocab object at 0x7fed89b82610>, 'utiliser': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c5d0>, 'taux': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ccd0>, 'occupation': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c690>, 'infrastructure': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cf50>, 'topographie': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c910>, 'ligne': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ce10>, 'flux': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ce90>, 'trafic': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c610>, 'etc': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ca90>, 'bleu': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c8d0>, 'couleur': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c1d0>, 'préférer': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c410>, 'aime': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cf10>, 'vert': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cd50>, 'test': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c110>, 'niveau': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c190>, 'français': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c050>, 'site': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c4d0>, 'internet': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c150>, 'école': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ca10>, 'mari': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c550>, 'boston': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ce50>, 'commerce': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cd90>, 'couloir': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c6d0>, 'place': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cb50>, 'financier': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8cc50>, 'arrive': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c310>, 'croiser': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c390>, 'jeune': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c990>, 'adulte': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8ced0>, 'an': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c090>, 'prévoir': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8c510>, 'ouvrir': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f3d0>, 'maison': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f790>, 'hôte': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8fa90>, 'quinzaine': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f350>, 'année': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8fa50>, 'histoire': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8fb10>, 'aimer': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f750>, 'médecin': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f210>, 'devoir': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f7d0>, 'boire': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f310>, 'verre': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f1d0>, 'vin': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f550>, 'rouge': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f150>, 'repas': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8fe10>, 'observer': <gensim.models.keyedvectors.Vocab object at 0x7fed89b8f050>, 'besoin':  ...

# %%
# Vector
v1 = word2vec.wv['terre'] 
v1
# Out:
# array([ 8.4133577e-03,  9.8535116e-04,  2.2277367e-04,  1.0086935e-03,
#        -7.4966918e-03,  4.8098611e-03, -4.1541643e-03, -8.3795888e-03,
#         7.3934281e-03, -8.3947852e-03,  9.3723238e-03, -6.1531500e-03,
#        -1.7779731e-03,  5.6585483e-03,  7.4813911e-03,  3.1548836e-03,
#         6.2705986e-03,  1.7565014e-04,  1.6378971e-03,  1.3400436e-03,
#        -4.7917590e-03,  2.1726771e-03, -1.3506782e-02, -9.5536644e-03,
#         1.9140635e-03, -3.5381578e-03,  2.9746022e-03, -8.6013688e-04,
#        -1.1578175e-03,  2.4893836e-03,  6.5850909e-03, -4.2576822e-03,
#        -6.4568585e-03,  4.5385347e-03,  6.5533398e-03, -1.0691172e-02,
#        -6.5869326e-04,  1.0250423e-03,  7.6828836e-03,  8.0429163e-04,
#        -3.5785339e-03, -8.1412951e-03,  3.3250533e-05, -5.4997443e-03,
#         3.1907958e-04, -4.2647626e-03, -1.3066997e-02,  6.8923733e-03,
#         1.3764003e-02,  8.4152948e-03,  5.0760820e-03, -1.6353776e-03,
#         1.1739316e-02,  5.7934658e-03, -6.5295901e-03, -1.1812364e-02,
#         1.6397834e-02, -3.4791771e-03, -1.2484875e-02,  1.7270064e-03,
#         7.3813787e-03,  5.0199050e-03,  1.9644136e-03, -3.6586146e-03,
#        -1.3021765e-03,  8.8030528e-03, -2.0649056e-03,  2.9515047e-03,
#         4.6710223e-03, -1.2694043e-04, -4.0472997e-03,  4.7795554e-03,
#        -7.1684155e-03,  5.4195826e-03, -4.3246578e-03,  5.3040409e-03,
#        -7.0219971e-03, -7.5873529e-04, -4.8867525e-03,  1.3429220e-03,
#         1.8391857e-03,  1.3124694e-03,  7.8799232e-04, -5.2747130e-04,
#         4.8835347e-03,  2.2538078e-03,  5.2870181e-03,  1.2083189e-02,
#         4.2894403e-03,  9.8313829e-03,  6.3902447e-03, -3.0503396e-03,
#         3.5111511e-03, -1.1719653e-03, -2.1924037e-03, -4.4482923e-03,
#         6.7948736e-03,  1.0369890e-02, -1.1039274e-02, -2.9982415e-03],
#       dtype=float32)

# %%
# Similar vectors/words
sim_words = word2vec.wv.most_similar('terre')
sim_words
# Out:
# [('grand', 0.8964307308197021),
#  ('pourcent', 0.8926550149917603),
#  ('enfant', 0.8903709650039673),
#  ('al', 0.8869612216949463),
#  ('pouvoir', 0.8797622323036194),
#  ('petit', 0.8767609596252441),
#  ('vie', 0.8756489753723145),
#  ('travail', 0.8746034502983093),
#  ('faire', 0.8741629719734192),
#  ('prendre', 0.8737356662750244)]

# %%
# Similarity between two words
word2vec.wv.similarity('terre', 'apprentissage')
# Out:
# 0.73694927

# %%
#### **** ***************** **** ####
#### **** RAW TEXT FEATURES **** ####
#### **** ***************** **** ####

# Count tokens per sentence
def count_token(sent):
  return(len(spacy_tokenizer(sent))) #spacy_tokenizer() to get tokens, len() to count them

# Count raw words per sentence
def count_words(sent):
  return(len(sent.split())) #split() gives us individual words, len() counts them

#Get average character length of word
def count_avg_word_character(sent):
  words = sent.split()
  return(sum(len(word) for word in words) / len(words))

def count_avg_token_character(sent):
  words = spacy_tokenizer(sent)
  if len(words) == 0:
    return(0)
  else:
    return(sum(len(word) for word in words) / len(words))

# %%
#### **** **************** **** ####
#### **** LEXICAL FEATURES **** ####
#### **** **************** **** ####

# Lexical Diversity
def lex_div_word(sent):
  total_number_word = len(sent.split())
  unique = set(sent.split())
  return(len(unique)/total_number_word)
#We don't apply for token, as the goal of the tokenzization is to be left with 
#unique tokens
#For tokens, we should apply to the whole text as done by tfidf_vector

# Lexical Density
def lex_den_tokens(sent):
  st = spacy_tokenizer(sent)
  string = " ".join([str(item) for item in st])
  x = sp(string)
  counter = 0 
  for token in x:
    if token.pos_ == "NOUN" or token.pos_ == "ADJ" or token.pos_ == "VERB" or token.pos_ == "ADV":
      counter = counter + 1
  if len(st) == 0:
    return(0)
  else:
    return(counter/len(st))

def lex_den_words(sent):
  x = sp(sent)
  counter = 0 
  for token in x:
    if token.pos_ == "NOUN" or token.pos_ == "ADJ" or token.pos_ == "VERB" or token.pos_ == "ADV":
      counter = counter + 1
  return(counter/len(x))

# Words NOT in frequent list
path = "https://raw.githubusercontent.com/Lirette2/DMML2021_Apple/main/data/list_words.csv"
words = pd.read_csv(path, index_col=0)


def words_list(sent):
  unique = set(sent.split())
  counter = 0
  for word_in_sentence in unique:
    for word_in_list in words.Mots:
      if word_in_sentence == word_in_list:
        counter = counter + 1
        break#we stop comparing once the word in found, to make it faster
  return(counter/len(unique))


def token_list(sent):
  unique = spacy_tokenizer(sent)
  counter = 0
  for word_in_sentence in unique:
    for word_in_list in words.Mots:
      if word_in_sentence == word_in_list:
        counter = counter + 1
        break#we stop comparing once the word in found, to make it faster
  return(counter/len(unique))

# %%
raw_word_count = pd.Series(texts.apply(count_words),name="raw_word_count")
token_count = pd.Series(texts.apply(count_token),name="token_count")
avg_chr_word = pd.Series(texts.apply(count_avg_word_character),name="avg_chr_word")
avg_chr_token = pd.Series(texts.apply(count_avg_token_character),name="avg_chr_token")
diversity_word = pd.Series(texts.apply(lex_div_word),name="diversity_word")
density_word = pd.Series(texts.apply(lex_den_words),name="density_word")
density_token = pd.Series(texts.apply(lex_den_tokens),name="density_token")
#freq_word_list = pd.Series(df.sentence.apply(words_not_list),name="freq_word_list")
freq_token_list = pd.Series(texts.apply(words_list),name="freq_token_list")

new_df = pd.concat([df,raw_word_count,token_count,avg_chr_word,avg_chr_token,
                    diversity_word,density_word,density_token,freq_token_list],axis=1)
new_df
# Out:
#                                                sentence  ... freq_token_list
# id                                                       ...
# 0     Les coûts kilométriques réels peuvent diverger...  ...        0.206897
# 1     Le bleu, c'est ma couleur préférée mais je n'a...  ...        0.416667
# 2     Le test de niveau en français est sur le site ...  ...        0.500000
# 3              Est-ce que ton mari est aussi de Boston?  ...        0.750000
# 4     Dans les écoles de commerce, dans les couloirs...  ...        0.285714
# ...                                                 ...  ...             ...
# 4795  C'est pourquoi, il décida de remplacer les hab...  ...        0.423077
# 4796  Il avait une de ces pâleurs splendides qui don...  ...        0.250000
# 4797  Et le premier samedi de chaque mois, venez ren...  ...        0.461538
# 4798  Les coûts liés à la journalisation n'étant pas...  ...        0.321429
# 4799  Sur le sable, la mer haletait de toute la resp...  ...        0.400000
#
# [4800 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
#Scale the data
scaler = MinMaxScaler()
col_to_scale = ["raw_word_count","token_count","avg_chr_word","avg_chr_token"]
#no need for the others because they already are on a scale from 0 to 1

df[col_to_scale]= scaler.fit_transform(new_df[col_to_scale])
df
# Out:
#                                                sentence  ... avg_chr_token
# id                                                       ...
# 0     Les coûts kilométriques réels peuvent diverger...  ...      0.615942
# 1     Le bleu, c'est ma couleur préférée mais je n'a...  ...      0.450000
# 2     Le test de niveau en français est sur le site ...  ...      0.486111
# 3              Est-ce que ton mari est aussi de Boston?  ...      0.416667
# 4     Dans les écoles de commerce, dans les couloirs...  ...      0.505208
# ...                                                 ...  ...           ...
# 4795  C'est pourquoi, il décida de remplacer les hab...  ...      0.625000
# 4796  Il avait une de ces pâleurs splendides qui don...  ...      0.475000
# 4797  Et le premier samedi de chaque mois, venez ren...  ...      0.555556
# 4798  Les coûts liés à la journalisation n'étant pas...  ...      0.708333
# 4799  Sur le sable, la mer haletait de toute la resp...  ...      0.520833
#
# [4800 rows x 6 columns]

# %% [markdown]
# ## Testing and training the model

# %%
# Select features
X = df[["sentence","raw_word_count","token_count","avg_chr_word","avg_chr_token"]]# the features we want to analyze

ylabels = df['difficulty'] # the labels, or answers, we want to test against

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.2, random_state=1234, stratify=ylabels)

X_train
# Out:
#                                                sentence  ...  avg_chr_token
# id                                                       ...
# 962   Le réalisateur m'a d'abord demandé de me mettr...  ...       0.645833
# 1886  Après quelques mois de cette pauvreté noble, a...  ...       0.511905
# 2721  L'indicateur n'était que de 40% chez les femme...  ...       0.638889
# 1025  L'objectif de ce type de voyage est d'être act...  ...       0.527778
# 4048  Et, en France, beaucoup moins de filles que de...  ...       0.500000
# ...                                                 ...  ...            ...
# 3693   Je vais prendre ma douche dans ma salle-de-bain.  ...       0.604167
# 3408  Après l'éruption de 1754, la plus grosse connu...  ...       0.561111
# 4289  Léonard est initié par Verrocchio aux nombreus...  ...       0.644444
# 3312  On en trouve des exemples dans l'ouvrage "L'in...  ...       0.694444
# 269   On peut aussi aller au théâtre, dans les musée...  ...       0.500000
#
# [3840 rows x 5 columns]

# %%
y_train
# Out:
# id
# 962     B1
# 1886    C1
# 2721    A2
# 1025    B1
# 4048    B2
#         ..
# 3693    A1
# 3408    B1
# 4289    C2
# 3312    C2
# 269     A1
# Name: difficulty, Length: 3840, dtype: object

# %%
from sklearn.compose import ColumnTransformer

# Define classifier
classifier = LogisticRegression(multi_class="multinomial",max_iter=1000)

#Vectorizer
tfidf_vector = TfidfVectorizer(tokenizer=spacy_tokenizer)

#Column Transformer (to apply vectorizer to the right column)
column_transformer = ColumnTransformer(
    [("tfidf", tfidf_vector, "sentence")],
    remainder="passthrough")

# Create pipeline
pipe = Pipeline([("tfidf",column_transformer),("classifier", classifier)])

# Fit model on training set
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tfidf',
#                                                   TfidfVectorizer(tokenizer=<function spacy_tokenizer at 0x7fed793d6680>),
#                                                   'sentence')])),
#                 ('classifier',
#                  LogisticRegression(max_iter=1000, multi_class='multinomial'))])

# %%
# Evaluate the model
def evaluate(test, pred):
  precision = precision_score(test, pred,average=None)
  recall = recall_score(test, pred, average=None)
  f1= f1_score(test, pred, average=None)
  print(f'CONFUSION MATRIX:\n{confusion_matrix(test, pred)}')
  print(f"ACCURACY SCORE:\n{accuracy_score(test, pred) :.4f}")
  print(f'CLASSIFICATION REPORT:')
  print("Precision:\t {0:4f}".format(precision_score(test, pred,average="macro"))) 
  print("Recall:\t {0:4f}".format(recall_score(test, pred, average="macro")))
  print("F1_Score:\t {0:4f}".format(f1_score(test, pred, average="macro")))

# %%
# Predictions
y_pred = pipe.predict(X_test)

# Evaluation - test set
evaluate(y_test, y_pred)
# Out:
# CONFUSION MATRIX:
# [[98 32 20 11  0  2]
#  [51 62 35  6  4  1]
#  [25 36 58 24  8  8]
#  [ 6  6 24 69 29 24]
#  [ 5  5  7 36 69 38]
#  [ 4  0  7 26 30 94]]
# ACCURACY SCORE:
# 0.4688
# CLASSIFICATION REPORT:
# Precision:	 0.466539
# Recall:	 0.467959
# F1_Score:	 0.465950
